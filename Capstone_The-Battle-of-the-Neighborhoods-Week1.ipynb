# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# This project will try to find best possible locations for opening a new restaurant **of any type** in **Los Angeles**. There are already many restaurants in Los Angeles, so the analysis will focus less dense areas of restaurants with medium or high population density. The neighborhoods surrounding our candidate locations should help provide insights into which type of restaurants might be successful, both from price point and cuisine perspective.
#
# The analysis will exclude unincorporated areas, as they tend to be of very low population density and do not make a good candidate for this type of analysis. Analysis will include all neighborhoods in L.A. County, as well as cities that are independant of L.A. county of which there are many (Beverley Hills, West Hollywood, etc.).
#
# Data science techniques wil be utilized to drive this analysis and recommendations.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on the problem statement, there will be a need for a list of all Los Angeles neighborhoods, with a way to filter out unincoprated areas, with latitude and longitude for each. This data set is then joined with data from FourSquare for Los Angeles restaurants.
#
# Los Angeles neightborhood data is available here:
#
# https://usc.data.socrata.com/api/views/9utn-waje/rows.csv?accessType=DOWNLOAD
#
# However the data set has bad data which make the data import challenging. The data set has been cleaned manually and placed here:
#
# http://glacier2.verio.com/data/la_neighborhoods.csv

# %% [markdown]
# ### Neighborhood Data

# %%
import pandas as pd

url = "http://glacier2.verio.com/data/la_neighborhoods.csv"

la_neighborhood_df = pd.read_csv(url)
print("Completed CSV Read")
# Out:
# Completed CSV Read

# %% [markdown]
# Let's take a look at the data set.

# %%
la_neighborhood_df.head()
# Out:
#                                    set             slug  \
# 0  L.A. County Neighborhoods (Current)            acton
# 1  L.A. County Neighborhoods (Current)  adams-normandie
# 2  L.A. County Neighborhoods (Current)     agoura-hills
# 3  L.A. County Neighborhoods (Current)       agua-dulce
# 4  L.A. County Neighborhoods (Current)         alhambra
#
#                                             the_geom  \
# 0  MULTIPOLYGON (((-118.20261747920541 34.5389897...
# 1  MULTIPOLYGON (((-118.30900800000012 34.0374109...
# 2  MULTIPOLYGON (((-118.76192500000009 34.1682029...
# 3  MULTIPOLYGON (((-118.2546773959221 34.55830403...
# 4  MULTIPOLYGON (((-118.12174700000014 34.1050399...
#
#                                  kind       external_i             name  \
# 0  L.A. County Neighborhood (Current)            acton            Acton
# 1  L.A. County Neighborhood (Current)  adams-normandie  Adams-Normandie
# 2  L.A. County Neighborhood (Current)     agoura-hills     Agoura Hills
# 3  L.A. County Neighborhood (Current)       agua-dulce       Agua Dulce
# 4  L.A. County Neighborhood (Current)         alhambra         Alhambra
#
#                                           display_na       sqmi  \
# 0           Acton L.A. County Neighborhood (Current)  39.339109
# 1  Adams-Normandie L.A. County Neighborhood (Curr...   0.805350
# 2    Agoura Hills L.A. County Neighborhood (Current)   8.146760
# 3      Agua Dulce L.A. County Neighborhood (Current)  31.462632
# 4        Alhambra L.A. County Neighborhood (Current)   7.623814
#
#                   type  name_1  slug_1    latitude  longitude  \
# 0  unincorporated-area     NaN     NaN -118.169810  34.497355
# 1    segment-of-a-city     NaN     NaN -118.300208  34.031461
# 2      standalone-city     NaN     NaN -118.759884  34.146736
# 3  unincorporated-area     NaN     NaN -118.317104  34.504927
# 4      standalone-city     NaN     NaN -118.136512  34.085539
#
#                                         location
# 0  POINT(34.497355239240846 -118.16981019229348)
# 1  POINT(34.031461499124156 -118.30020800000011)
# 2  POINT(34.146736499122795 -118.75988450000015)
# 3   POINT(34.504926999796837 -118.3171036690717)
# 4  POINT(34.085538999123571 -118.13651200000021)

# %% [markdown]
# The key fields that will be used are are name, type, and latitude and longitude.

# %%
la_neighborhood_df.shape
# Out:
# (269, 14)

# %% [markdown]
# 269 distinct neightborhoods. Now let's remove the unincoporated areas.

# %%
# Ignore unincorporated areas
options = ['segment-of-a-city', 'standalone-city'] 
    
# selecting rows based on condition 
rslt_df = la_neighborhood_df.loc[la_neighborhood_df['type'].isin(options)]

# %%
rslt_df.shape
# Out:
# (199, 14)

# %% [markdown]
# 70 unicorporated areas have been removed. Let's subset and correct the data set.

# %%
la_neigh_df = rslt_df[["name", "type", "latitude", "longitude"]]

# It appears latitude and longitude are reversed, so perform a rename

la_neigh_df.rename(columns={"latitude": "lng", "longitude": "lat"}, inplace=True)

la_neigh_df.columns
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Index(['name', 'type', 'lng', 'lat'], dtype='object')

# %%
# Finally check some of the data
la_neigh_df.head()
# Out:
#               name               type         lng        lat
# 1  Adams-Normandie  segment-of-a-city -118.300208  34.031461
# 2     Agoura Hills    standalone-city -118.759884  34.146736
# 4         Alhambra    standalone-city -118.136512  34.085539
# 6          Artesia    standalone-city -118.080101  33.866896
# 9          Arcadia    standalone-city -118.030419  34.133230

# %% [markdown]
# ### Restaurant Data

# %% [markdown]
# Pull restaurant data down from Foursquare.

# %%
#!pip install geopy
# Out:
# Collecting geopy
#   Using cached https://files.pythonhosted.org/packages/0c/67/915668d0e286caa21a1da82a85ffe3d20528ec7212777b43ccd027d94023/geopy-2.1.0-py3-none-any.whl
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Using cached https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0

# %%
import geopy
# Out:
# C:\Users\Daniel\Anaconda3
# base

# %%
# Get Los Angeles latitude and longitude
from geopy.geocoders import Nominatim 

# Get the coordinates of Los Angeles
address = 'Los Angeles'

geolocator = Nominatim(user_agent="la_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Los Angeles latitude and longitude: {}, {}.'.format(latitude, longitude))
# Out:
# Los Angeles latitude and longitude: 34.0536909, -118.242766.

# %% [markdown]
# Use folium and map Los Angeles as a starting point, along with our neighborhood data frame.

# %%
# !pip install folium
# Out:
# Collecting folium
#   Using cached https://files.pythonhosted.org/packages/c3/83/e8cb37afc2f016a1cf4caab8d22caf7fe4156c4c15230d8abc9c83547e0c/folium-0.12.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\daniel\anaconda3\lib\site-packages (from folium) (1.16.2)
# Requirement already satisfied: requests in c:\users\daniel\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\daniel\anaconda3\lib\site-packages (from folium) (2.10)
# Collecting branca>=0.3.0 (from folium)
#   Using cached https://files.pythonhosted.org/packages/61/1f/570b0615c452265d57e4114e633231d6cd9b9d275256778a675681e4f711/branca-0.4.2-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniel\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\daniel\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\daniel\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\daniel\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1

# %%
import folium

la_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# Markers
for lat, lng, name, type_loc in zip(la_neigh_df['lat'], la_neigh_df['lng'], la_neigh_df['name'], la_neigh_df['type']): 
    #print(name)
    label = '{},{}'.format(name, type_loc)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=20,
        popup=label,
        color='gray',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(la_map)

# %%
la_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0bdee73de34249a3a0bcca583aee4a4a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0bdee73de34249a3a0bcca583aee4a4a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0bdee73de34249a3a0bcca583aee4a4a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0bdee73de34249a3a0bcca583aee4a4a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.0536909%2C%20-118.242766%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# FourSquare set up
CLIENT_ID = 'O0HJUMSBLMA4FOPTXPXA0IO0P4DEWM2XMKD0IJ5Q0ZJRPUV3' # your Foursquare 
CLIENT_SECRET = 'O0L2WTWXSGY10DARU2CBPI450RB00LARJRIZ5FZ2KF01GQYW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
radius = 500


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# Your credentails:
# CLIENT_ID: O0HJUMSBLMA4FOPTXPXA0IO0P4DEWM2XMKD0IJ5Q0ZJRPUV3
# CLIENT_SECRET:O0L2WTWXSGY10DARU2CBPI450RB00LARJRIZ5FZ2KF01GQYW
# 'https://api.foursquare.com/v2/venues/search?client_id=O0HJUMSBLMA4FOPTXPXA0IO0P4DEWM2XMKD0IJ5Q0ZJRPUV3&client_secret=O0L2WTWXSGY10DARU2CBPI450RB00LARJRIZ5FZ2KF01GQYW&ll=34.0536909,-118.242766&v=20180604&radius=500&limit=100'

# %%
# Function to retrieve venue categories
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import requests
from pandas.io.json import json_normalize

# Results from the GET
results = requests.get(url).json()
results

# Pull out the venues
venues = results['response']['venues']

# dataframe
venues_dataframe = json_normalize(venues)
venues_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...         NaN
# 1  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...         NaN
# 2  [{'id': '4bf58dd8d48988d129941735', 'name': 'C...         NaN
# 3  [{'id': '4bf58dd8d48988d129941735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d129941735', 'name': 'C...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id       location.address  ...  \
# 0  52ebf057498ee83c88d9c1f9                    NaN  ...
# 1  4d65fb1dc2ccb60ca24c6bac        200 N Spring St  ...
# 2  4b38d6b3f964a520fb5025e3          200 N Main St  ...
# 3  4b5113edf964a520314127e3        200 N Spring St  ...
# 4  4d9ccfabc593a1cd8dff5119  Los Angeles City Hall  ...
#
#                            location.formattedAddress  \
# 0                   [Los Angeles, CA, United States]
# 1  [200 N Spring St, Los Angeles, CA 90012, Unite...
# 2  [200 N Main St (Temple Street), Los Angeles, C...
# 3  [200 N Spring St (at Temple Ave), Los Angeles,...
# 4  [Los Angeles City Hall, Los Angeles, CA 90012,...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 34.05378746696942...    34.053787
# 1  [{'label': 'display', 'lat': 34.05415339478075...    34.054153
# 2  [{'label': 'display', 'lat': 34.05301072481605...    34.053011
# 3  [{'label': 'display', 'lat': 34.05348417688625...    34.053484
# 4  [{'label': 'display', 'lat': 34.05393149240509...    34.053931
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0  -118.242369                    NaN                 NaN             CA
# 1  -118.243117                    NaN               90012             CA
# 2  -118.241863                    NaN               90012             CA
# 3  -118.242478           Civic Center               90012             CA
# 4  -118.243169                    NaN               90012             CA
#
#                                                 name    referralId  \
# 0  Los Angeles Mayor's Office of Economic Develop...  v-1624285480
# 1                           Los Angeles Civic Center  v-1624285480
# 2              James K. Hahn City Hall East Building  v-1624285480
# 3                              Los Angeles City Hall  v-1624285480
# 4                      Office of Mayor Eric Garcetti  v-1624285480
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3     75727220
# 4          NaN
#
# [5 rows x 25 columns]

# %%
# Filter the categories and clean up the venue names
filtered_columns = ['name', 'categories'] + [col for col in venues_dataframe.columns if col.startswith('location.')] + ['id']
venues_df_filtered = venues_dataframe.loc[:, filtered_columns]
venues_df_filtered['categories'] = venues_df_filtered.apply(get_category_type, axis=1)
venues_df_filtered.columns = [column.split('.')[-1] for column in venues_df_filtered.columns]
venues_df_filtered.head()
# Out:
#                                                 name           categories  \
# 0  Los Angeles Mayor's Office of Economic Develop...  Government Building
# 1                           Los Angeles Civic Center  Government Building
# 2              James K. Hahn City Hall East Building            City Hall
# 3                              Los Angeles City Hall            City Hall
# 4                      Office of Mayor Eric Garcetti            City Hall
#
#                  address  cc         city        country    crossStreet  \
# 0                    NaN  US  Los Angeles  United States            NaN
# 1        200 N Spring St  US  Los Angeles  United States            NaN
# 2          200 N Main St  US  Los Angeles  United States  Temple Street
# 3        200 N Spring St  US  Los Angeles  United States  at Temple Ave
# 4  Los Angeles City Hall  US  Los Angeles  United States            NaN
#
#    distance                                   formattedAddress  \
# 0        38                   [Los Angeles, CA, United States]
# 1        60  [200 N Spring St, Los Angeles, CA 90012, Unite...
# 2       112  [200 N Main St (Temple Street), Los Angeles, C...
# 3        35  [200 N Spring St (at Temple Ave), Los Angeles,...
# 4        45  [Los Angeles City Hall, Los Angeles, CA 90012,...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 34.05378746696942...  34.053787 -118.242369
# 1  [{'label': 'display', 'lat': 34.05415339478075...  34.054153 -118.243117
# 2  [{'label': 'display', 'lat': 34.05301072481605...  34.053011 -118.241863
# 3  [{'label': 'display', 'lat': 34.05348417688625...  34.053484 -118.242478
# 4  [{'label': 'display', 'lat': 34.05393149240509...  34.053931 -118.243169
#
#    neighborhood postalCode state                        id
# 0           NaN        NaN    CA  52ebf057498ee83c88d9c1f9
# 1           NaN      90012    CA  4d65fb1dc2ccb60ca24c6bac
# 2           NaN      90012    CA  4b38d6b3f964a520fb5025e3
# 3  Civic Center      90012    CA  4b5113edf964a520314127e3
# 4           NaN      90012    CA  4d9ccfabc593a1cd8dff5119

# %%
# Check the size
venues_df_filtered.shape
# Out:
# (100, 16)

# %%
# Nearby venues function
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        #print(lat)
        #print(lng)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lng, 
            lat, 
            radius, 
            LIMIT)
            
        #print(url)
        
        # make the GET request
        #results = requests.get(url).json()["response"]['groups'][0]['items']
        results = requests.get(url).json()['response'].get('groups',[{}])[0].get('items', [])
        
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# 2540                  e-Motion Training       34.158111      -118.615593
# 2541         Deats Stewart Deats Design       34.159030      -118.612447
# 2542                             F or D       34.158239      -118.618153
# 2543  Woodland Hills Carpet Restoration       34.158725      -118.618393
# 2544            Trunk Peter Productions       34.162271      -118.613903
#
#                  Venue Category
# 0             Convenience Store
# 1                   Gas Station
# 2                          Food
# 3              Sushi Restaurant
# 4              Sushi Restaurant
# 5                    Taco Place
# 6     Latin American Restaurant
# 7              Recording Studio
# 8              Sushi Restaurant
# 9                     Bookstore
# 10                   Playground
# 11                Grocery Store
# 12                         Park
# 13         Fast Food Restaurant
# 14             Sushi Restaurant
# 15                Grocery Store
# 16                         Café
# 17               Breakfast Spot
# 18                   Restaurant
# 19            Indian Restaurant
# 20                    BBQ Joint
# 21                 Burger Joint
# 22          American Restaurant
# 23                  Pizza Place
# 24                      Brewery
# 25                  Gas Station
# 26                  Gas Station
# 27              Thai Restaurant
# 28                Deli / Bodega
# 29               Shipping Store
# ...                         ...
# 2515             Discount Store
# 2516          Convenience Store
# 2517       Fast Food Restaurant
# 2518       Fast Food Restaurant
# 2519  Latin American Restaurant
# 2520           Insurance Office
# 2521                Pizza Place
# 2522                 Food Truck
# 2523             Scenic Lookout
# 2524                    Dog Run
# 2525       Gym / Fitness Center
# 2526          Convenience Store
# 2527                        Bar
# 2528  Latin American Restaurant
# 2529             Ice Cream Shop
# 2530           Business Service
# 2531        Filipino Restaurant
# 2532              Grocery Store
# 2533  South American Restaurant
# 2534        Fried Chicken Joint
# 2535               Home Service
# 2536           Business Service
# 2537       Fast Food Restaurant
# 2538                 Donut Shop
# 2539                     Bakery
# 2540       Gym / Fitness Center
# 2541                   Wine Bar
# 2542       Arts & Entertainment
# 2543               Carpet Store
# 2544               Concert Hall
#
# [2545 rows x 7 columns]

# %%
la_venues.groupby('Neighborhood').count()
# Out:
#                         Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Acton                                      13                      13     13
# Adams-Normandie                            30                      30     30
# Agoura Hills                               14                      14     14
# Agua Dulce                                 26                      26     26
# Alhambra                                   26                      26     26
# Alondra Park                                5                       5      5
# Altadena                                   22                      22     22
# Angeles Crest                               4                       4      4
# Arcadia                                    10                      10     10
# Arleta                                      8                       8      8
# Arlington Heights                           5                       5      5
# Artesia                                    26                      26     26
# Athens                                      6                       6      6
# Atwater Village                             3                       3      3
# Avalon                                     14                      14     14
# Avocado Heights                            11                      11     11
# Azusa                                       2                       2      2
# Baldwin Hills/Crenshaw                    100                     100    100
# Baldwin Park                               17                      17     17
# Bel-Air                                    73                      73     73
# Bell                                        2                       2      2
# Bell Gardens                                5                       5      5
# Bellflower                                  2                       2      2
# Beverly Crest                               2                       2      2
# Beverly Grove                               7                       7      7
# Beverlywood                                16                      16     16
# Boyle Heights                               1                       1      1
# Bradbury                                    3                       3      3
# Brentwood                                  51                      51     51
# Broadway-Manchester                         4                       4      4
# ...                                       ...                     ...    ...
# Palos Verdes Estates                       14                      14     14
# Panorama City                               2                       2      2
# Paramount                                  15                      15     15
# Pasadena                                   39                      39     39
# Pico Rivera                                53                      53     53
# Pico-Robertson                             32                      32     32
# Pico-Union                                 13                      13     13
# Playa Vista                                 4                       4      4
# Playa del Rey                              18                      18     18
# Pomona                                      4                       4      4
# Porter Ranch                                2                       2      2
# Quartz Hill                                 2                       2      2
# Ramona                                      5                       5      5
# Rancho Dominguez                            8                       8      8
# Rancho Palos Verdes                         8                       8      8
# Rancho Park                                31                      31     31
# Redondo Beach                              45                      45     45
# Reseda                                     57                      57     57
# Ridge Route                                26                      26     26
# Rolling Hills Estates                      10                      10     10
# Rosemead                                   10                      10     10
# Rowland Heights                             4                       4      4
# San Dimas                                   6                       6      6
# Santa Fe Springs                           13                      13     13
# Vermont Square                             29                      29     29
# Vermont Vista                              47                      47     47
# Walnut Park                                 3                       3      3
# Watts                                       4                       4      4
# West Adams                                 12                      12     12
# West Carson                                 4                       4      4
#
#                         Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Acton                               13               13              13
# Adams-Normandie                     30               30              30
# Agoura Hills                        14               14              14
# Agua Dulce                          26               26              26
# Alhambra                            26               26              26
# Alondra Park                         5                5               5
# Altadena                            22               22              22
# Angeles Crest                        4                4               4
# Arcadia                             10               10              10
# Arleta                               8                8               8
# Arlington Heights                    5                5               5
# Artesia                             26               26              26
# Athens                               6                6               6
# Atwater Village                      3                3               3
# Avalon                              14               14              14
# Avocado Heights                     11               11              11
# Azusa                                2                2               2
# Baldwin Hills/Crenshaw             100              100             100
# Baldwin Park                        17               17              17
# Bel-Air                             73               73              73
# Bell                                 2                2               2
# Bell Gardens                         5                5               5
# Bellflower                           2                2               2
# Beverly Crest                        2                2               2
# Beverly Grove                        7                7               7
# Beverlywood                         16               16              16
# Boyle Heights                        1                1               1
# Bradbury                             3                3               3
# Brentwood                           51               51              51
# Broadway-Manchester                  4                4               4
# ...                                ...              ...             ...
# Palos Verdes Estates                14               14              14
# Panorama City                        2                2               2
# Paramount                           15               15              15
# Pasadena                            39               39              39
# Pico Rivera                         53               53              53
# Pico-Robertson                      32               32              32
# Pico-Union                          13               13              13
# Playa Vista                          4                4               4
# Playa del Rey                       18               18              18
# Pomona                               4                4               4
# Porter Ranch                         2                2               2
# Quartz Hill                          2                2               2
# Ramona                               5                5               5
# Rancho Dominguez                     8                8               8
# Rancho Palos Verdes                  8                8               8
# Rancho Park                         31               31              31
# Redondo Beach                       45               45              45
# Reseda                              57               57              57
# Ridge Route                         26               26              26
# Rolling Hills Estates               10               10              10
# Rosemead                            10               10              10
# Rowland Heights                      4                4               4
# San Dimas                            6                6               6
# Santa Fe Springs                    13               13              13
# Vermont Square                      29               29              29
# Vermont Vista                       47               47              47
# Walnut Park                          3                3               3
# Watts                                4                4               4
# West Adams                          12               12              12
# West Carson                          4                4               4
#
# [184 rows x 6 columns]

# %%
print('Number of unique categories is {}.'.format(len(la_venues['Venue Category'].unique())))
# Out:
# Number of unique categories is 290.

# %% [markdown]
# Finally, filter out all venues that are not restaurants.

# %%
options = ['Fast Food Restaurant' ,'Breakfast Spot',
 'Café', 'Restaurant', 'Indian Restaurant', 'BBQ Joint' ,'Burger Joint',
 'American Restaurant', 'Pizza Place', 'Brewery' 'Thai Restaurant',
 'Deli / Bodega', 'Mexican Restaurant','Sushi Restaurant' , 'Taco Place',
 'Hawaiian Restaurant',
 'Taiwanese Restaurant', 'Vegetarian / Vegan Restaurant',
 'Vietnamese Restaurant' ,'Japanese Restaurant' ,
 'Korean Restaurant', 
 'Donburi Restaurant', 'Seafood Restaurant',  'Dumpling Restaurant',
 'Mediterranean Restaurant', 'Southern / Soul Food Restaurant' 'Diner',
 'Udon Restaurant', 'Empanada Restaurant', 'Ramen Restaurant' 'Cuban Restaurant',
 'Korean BBQ Restaurant', 'Hotel Bar', 'Brazilian Restaurant', 'Ethiopian Restaurant',
 'French Restaurant', 'Cajun / Creole Restaurant' ,'Filipino Restaurant',
 'Dim Sum Restaurant',  'Greek Restaurant' ,'Noodle House' , 'New American Restaurant',
 'Middle Eastern Restaurant', 'Falafel Restaurant',
 'Persian Restaurant', 'Caribbean Restaurant', 'Andhra Restaurant' ,
 'Russian Restaurant'
  ] 

# selecting rows based on condition 
la_rest_df = la_venues.loc[la_venues['Venue Category'].isin(options)] 
la_rest_df
# Out:
#                Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 3                     Acton            -118.300208               34.031461
# 4                     Acton            -118.300208               34.031461
# 5                     Acton            -118.300208               34.031461
# 8                     Acton            -118.300208               34.031461
# 13          Adams-Normandie            -118.759884               34.146736
# 14          Adams-Normandie            -118.759884               34.146736
# 16          Adams-Normandie            -118.759884               34.146736
# 17          Adams-Normandie            -118.759884               34.146736
# 18          Adams-Normandie            -118.759884               34.146736
# 19          Adams-Normandie            -118.759884               34.146736
# 20          Adams-Normandie            -118.759884               34.146736
# 21          Adams-Normandie            -118.759884               34.146736
# 22          Adams-Normandie            -118.759884               34.146736
# 23          Adams-Normandie            -118.759884               34.146736
# 28          Adams-Normandie            -118.759884               34.146736
# 30          Adams-Normandie            -118.759884               34.146736
# 35          Adams-Normandie            -118.759884               34.146736
# 36          Adams-Normandie            -118.759884               34.146736
# 38          Adams-Normandie            -118.759884               34.146736
# 39          Adams-Normandie            -118.759884               34.146736
# 42          Adams-Normandie            -118.759884               34.146736
# 44             Agoura Hills            -118.136512               34.085539
# 46             Agoura Hills            -118.136512               34.085539
# 50             Agoura Hills            -118.136512               34.085539
# 51             Agoura Hills            -118.136512               34.085539
# 57               Agua Dulce            -118.080101               33.866896
# 58               Agua Dulce            -118.080101               33.866896
# 60               Agua Dulce            -118.080101               33.866896
# 61               Agua Dulce            -118.080101               33.866896
# 63               Agua Dulce            -118.080101               33.866896
# ...                     ...                    ...                     ...
# 2423                 Reseda            -118.369613               34.087213
# 2424                 Reseda            -118.369613               34.087213
# 2427                 Reseda            -118.369613               34.087213
# 2431                 Reseda            -118.369613               34.087213
# 2438  Rolling Hills Estates            -118.272221               34.062361
# 2441  Rolling Hills Estates            -118.272221               34.062361
# 2448  The Landing Grill & Sushi Bar       34.138662      -118.823038
# 2449           Zin Bistro Americana       34.139325      -118.823601
# 2455        California Chicken Cafe       34.046434      -118.434128
# 2456                 Tacos Tu Madre       34.047562      -118.434983
# 2458                Taste of Tehran       34.047817      -118.435161
# 2459               That Pizza Place       34.044471      -118.431819
# 2460                    Poquito Mas       34.043239      -118.431712
# 2461                          Necco       34.047640      -118.435004
# 2462                  Pitfire Pizza       34.046502      -118.433880
# 2465                   Zuma Kitchen       34.047611      -118.434759
# 2467               California Fresh       34.046700      -118.434024
# 2476             The Room Sushi Bar       34.048453      -118.435527
# 2482          India's Oven Westwood       34.048366      -118.435465
# 2483                     Farsi Cafe       34.047947      -118.434953
# 2491                    Blaze Pizza       34.068379      -118.442360
# 2498                    Chick-fil-A       34.063509      -118.445144
# 2507                      SEAS Café       34.068954      -118.442963
# 2514                 Domino's Pizza       33.790648      -118.262836
# 2517                  El Pollo Loco       33.790963      -118.263056
# 2518                      Taco Bell       33.790980      -118.263598
# 2521                   Pronto Pizza       33.790799      -118.264395
# 2531                   Kalesa Grill       34.208645      -118.572712
# 2537      Carl's Jr / Green Burrito       34.208568      -118.571805
#
#                 Venue Category
# 3             Sushi Restaurant
# 4             Sushi Restaurant
# 5                   Taco Place
# 8             Sushi Restaurant
# 13        Fast Food Restaurant
# 14            Sushi Restaurant
# 16                        Café
# 17              Breakfast Spot
# 18                  Restaurant
# 19           Indian Restaurant
# 20                   BBQ Joint
# 21                Burger Joint
# 22         American Restaurant
# 23                 Pizza Place
# 28               Deli / Bodega
# 30          Mexican Restaurant
# 35              Breakfast Spot
# 36        Fast Food Restaurant
# 38        Fast Food Restaurant
# 39        Fast Food Restaurant
# 42         American Restaurant
# 44                 Pizza Place
# 46        Fast Food Restaurant
# 50          Mexican Restaurant
# 51              Breakfast Spot
# 57           Indian Restaurant
# 58           Indian Restaurant
# 60           Indian Restaurant
# 61           Indian Restaurant
# 63           Indian Restaurant
# ...                        ...
# 2423          Sushi Restaurant
# 2424       American Restaurant
# 2427       American Restaurant
# 2431                      Café
# 2438      Fast Food Restaurant
# 2441      Fast Food Restaurant
# 2442      Fast Food Restaurant
# 2448          Sushi Restaurant
# 2449       American Restaurant
# 2455       American Restaurant
# 2456                Taco Place
# 2458        Persian Restaurant
# 2459               Pizza Place
# 2460        Mexican Restaurant
# 2461       Japanese Restaurant
# 2462               Pizza Place
# 2465  Mediterranean Restaurant
# 2467  Mediterranean Restaurant
# 2476          Sushi Restaurant
# 2482         Indian Restaurant
# 2483        Persian Restaurant
# 2491               Pizza Place
# 2498      Fast Food Restaurant
# 2507                      Café
# 2514               Pizza Place
# 2517      Fast Food Restaurant
# 2518      Fast Food Restaurant
# 2521               Pizza Place
# 2531       Filipino Restaurant
# 2537      Fast Food Restaurant
#
# [702 rows x 7 columns]

# %% [markdown]
# We now have two datasets, one, the neightborhoods, the other, restaurants. We will combine and use these datasets to perform analysis.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>
