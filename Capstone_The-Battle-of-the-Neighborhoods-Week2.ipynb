# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# This project will try to find best possible locations for opening a new restaurant **of any type** in **Los Angeles**. There are already many restaurants in Los Angeles, so the analysis will focus less dense areas of restaurants with medium or high population density. The neighborhoods surrounding our candidate locations should help provide insights into which type of restaurants might be successful, both from price point and cuisine perspective.
#
# The analysis will exclude unincorporated areas, as they tend to be of very low population density and do not make a good candidate for this type of analysis. Analysis will include all neighborhoods in L.A. County, as well as cities that are independant of L.A. county of which there are many (Beverley Hills, West Hollywood, etc.).
#
# Data science techniques wil be utilized to drive this analysis and recommendations.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on the problem statement, there will be a need for a list of all Los Angeles neighborhoods, with a way to filter out unincoprated areas, with latitude and longitude for each. This data set is then joined with data from FourSquare for Los Angeles restaurants.
#
# Los Angeles neightborhood data is available here:
#
# https://usc.data.socrata.com/api/views/9utn-waje/rows.csv?accessType=DOWNLOAD
#
# However the data set has bad data which make the data import challenging. The data set has been cleaned manually and placed here:
#
# http://glacier2.verio.com/data/la_neighborhoods.csv

# %% [markdown]
# ### Neighborhood Data

# %%
import pandas as pd

url = "http://glacier2.verio.com/data/la_neighborhoods.csv"

la_neighborhood_df = pd.read_csv(url)
print("Completed CSV Read")
# Out:
# Completed CSV Read

# %% [markdown]
# Let's take a look at the data set.

# %%
la_neighborhood_df.head()
# Out:
#                                    set             slug  \
# 0  L.A. County Neighborhoods (Current)            acton
# 1  L.A. County Neighborhoods (Current)  adams-normandie
# 2  L.A. County Neighborhoods (Current)     agoura-hills
# 3  L.A. County Neighborhoods (Current)       agua-dulce
# 4  L.A. County Neighborhoods (Current)         alhambra
#
#                                             the_geom  \
# 0  MULTIPOLYGON (((-118.20261747920541 34.5389897...
# 1  MULTIPOLYGON (((-118.30900800000012 34.0374109...
# 2  MULTIPOLYGON (((-118.76192500000009 34.1682029...
# 3  MULTIPOLYGON (((-118.2546773959221 34.55830403...
# 4  MULTIPOLYGON (((-118.12174700000014 34.1050399...
#
#                                  kind       external_i             name  \
# 0  L.A. County Neighborhood (Current)            acton            Acton
# 1  L.A. County Neighborhood (Current)  adams-normandie  Adams-Normandie
# 2  L.A. County Neighborhood (Current)     agoura-hills     Agoura Hills
# 3  L.A. County Neighborhood (Current)       agua-dulce       Agua Dulce
# 4  L.A. County Neighborhood (Current)         alhambra         Alhambra
#
#                                           display_na       sqmi  \
# 0           Acton L.A. County Neighborhood (Current)  39.339109
# 1  Adams-Normandie L.A. County Neighborhood (Curr...   0.805350
# 2    Agoura Hills L.A. County Neighborhood (Current)   8.146760
# 3      Agua Dulce L.A. County Neighborhood (Current)  31.462632
# 4        Alhambra L.A. County Neighborhood (Current)   7.623814
#
#                   type  name_1  slug_1    latitude  longitude  \
# 0  unincorporated-area     NaN     NaN -118.169810  34.497355
# 1    segment-of-a-city     NaN     NaN -118.300208  34.031461
# 2      standalone-city     NaN     NaN -118.759884  34.146736
# 3  unincorporated-area     NaN     NaN -118.317104  34.504927
# 4      standalone-city     NaN     NaN -118.136512  34.085539
#
#                                         location
# 0  POINT(34.497355239240846 -118.16981019229348)
# 1  POINT(34.031461499124156 -118.30020800000011)
# 2  POINT(34.146736499122795 -118.75988450000015)
# 3   POINT(34.504926999796837 -118.3171036690717)
# 4  POINT(34.085538999123571 -118.13651200000021)

# %% [markdown]
# The key fields that will be used are are name, type, and latitude and longitude.

# %%
la_neighborhood_df.shape
# Out:
# (269, 14)

# %% [markdown]
# 269 distinct neightborhoods. Now let's remove the unincoporated areas.

# %%
# Ignore unincorporated areas
options = ['segment-of-a-city', 'standalone-city'] 
    
# selecting rows based on condition 
rslt_df = la_neighborhood_df.loc[la_neighborhood_df['type'].isin(options)]

# %%
rslt_df.shape
# Out:
# (199, 14)

# %% [markdown]
# 70 unicorporated areas have been removed. Let's subset and correct the data set.

# %%
la_neigh_df = rslt_df[["name", "type", "latitude", "longitude"]]

# It appears latitude and longitude are reversed, so perform a rename

la_neigh_df.rename(columns={"latitude": "lng", "longitude": "lat"}, inplace=True)

la_neigh_df.columns
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Index(['name', 'type', 'lng', 'lat'], dtype='object')

# %%
# Finally check some of the data
la_neigh_df.head()
# Out:
#               name               type         lng        lat
# 1  Adams-Normandie  segment-of-a-city -118.300208  34.031461
# 2     Agoura Hills    standalone-city -118.759884  34.146736
# 4         Alhambra    standalone-city -118.136512  34.085539
# 6          Artesia    standalone-city -118.080101  33.866896
# 9          Arcadia    standalone-city -118.030419  34.133230

# %% [markdown]
# ### Restaurant Data

# %% [markdown]
# Pull restaurant data down from Foursquare.

# %%
#!pip install geopy

# %%
import geopy

# %%
# Get Los Angeles latitude and longitude
from geopy.geocoders import Nominatim 

# Get the coordinates of Los Angeles
address = 'Los Angeles'

geolocator = Nominatim(user_agent="la_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Los Angeles latitude and longitude: {}, {}.'.format(latitude, longitude))
# Out:
# Los Angeles latitude and longitude: 34.0536909, -118.242766.

# %% [markdown]
# Use folium and map Los Angeles as a starting point, along with our neighborhood data frame.

# %%
#!pip install folium

# %%
import folium

la_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# Markers
for lat, lng, name, type_loc in zip(la_neigh_df['lat'], la_neigh_df['lng'], la_neigh_df['name'], la_neigh_df['type']): 
    #print(name)
    label = '{},{}'.format(name, type_loc)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=20,
        popup=label,
        color='gray',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(la_map)

# %%
la_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_04f4b900ad334a8aaac93722d11fd65b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_04f4b900ad334a8aaac93722d11fd65b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_04f4b900ad334a8aaac93722d11fd65b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_04f4b900ad334a8aaac93722d11fd65b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.0536909%2C%20-118.242766%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# FourSquare set up
CLIENT_ID = 'O0HJUMSBLMA4FOPTXPXA0IO0P4DEWM2XMKD0IJ5Q0ZJRPUV3' # your Foursquare 
CLIENT_SECRET = 'O0L2WTWXSGY10DARU2CBPI450RB00LARJRIZ5FZ2KF01GQYW' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
radius = 500


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# Your credentails:
# CLIENT_ID: O0HJUMSBLMA4FOPTXPXA0IO0P4DEWM2XMKD0IJ5Q0ZJRPUV3
# CLIENT_SECRET:O0L2WTWXSGY10DARU2CBPI450RB00LARJRIZ5FZ2KF01GQYW
# 'https://api.foursquare.com/v2/venues/search?client_id=O0HJUMSBLMA4FOPTXPXA0IO0P4DEWM2XMKD0IJ5Q0ZJRPUV3&client_secret=O0L2WTWXSGY10DARU2CBPI450RB00LARJRIZ5FZ2KF01GQYW&ll=34.0536909,-118.242766&v=20180604&radius=500&limit=100'

# %%
# Function to retrieve venue categories
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import requests
from pandas.io.json import json_normalize

# Results from the GET
results = requests.get(url).json()
results

# Pull out the venues
venues = results['response']['venues']

# dataframe
venues_dataframe = json_normalize(venues)
venues_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...         NaN
# 1  [{'id': '4bf58dd8d48988d129941735', 'name': 'C...         NaN
# 2  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...         NaN
# 3  [{'id': '4bf58dd8d48988d129941735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d129941735', 'name': 'C...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id       location.address  ...  \
# 0  52ebf057498ee83c88d9c1f9                    NaN  ...
# 1  4b38d6b3f964a520fb5025e3          200 N Main St  ...
# 2  4d65fb1dc2ccb60ca24c6bac        200 N Spring St  ...
# 3  4b5113edf964a520314127e3        200 N Spring St  ...
# 4  4d9ccfabc593a1cd8dff5119  Los Angeles City Hall  ...
#
#                            location.formattedAddress  \
# 0                   [Los Angeles, CA, United States]
# 1  [200 N Main St (Temple Street), Los Angeles, C...
# 2  [200 N Spring St, Los Angeles, CA 90012, Unite...
# 3  [200 N Spring St (at Temple Ave), Los Angeles,...
# 4  [Los Angeles City Hall, Los Angeles, CA 90012,...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 34.05378746696942...    34.053787
# 1  [{'label': 'display', 'lat': 34.05301072481605...    34.053011
# 2  [{'label': 'display', 'lat': 34.05415339478075...    34.054153
# 3  [{'label': 'display', 'lat': 34.05348417688625...    34.053484
# 4  [{'label': 'display', 'lat': 34.05393149240509...    34.053931
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0  -118.242369                    NaN                 NaN             CA
# 1  -118.241863                    NaN               90012             CA
# 2  -118.243117                    NaN               90012             CA
# 3  -118.242478           Civic Center               90012             CA
# 4  -118.243169                    NaN               90012             CA
#
#                                                 name    referralId  \
# 0  Los Angeles Mayor's Office of Economic Develop...  v-1624387346
# 1              James K. Hahn City Hall East Building  v-1624387346
# 2                           Los Angeles Civic Center  v-1624387346
# 3                              Los Angeles City Hall  v-1624387346
# 4                      Office of Mayor Eric Garcetti  v-1624387346
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3     75727220
# 4          NaN
#
# [5 rows x 25 columns]

# %%
# Filter the categories and clean up the venue names
filtered_columns = ['name', 'categories'] + [col for col in venues_dataframe.columns if col.startswith('location.')] + ['id']
venues_df_filtered = venues_dataframe.loc[:, filtered_columns]
venues_df_filtered['categories'] = venues_df_filtered.apply(get_category_type, axis=1)
venues_df_filtered.columns = [column.split('.')[-1] for column in venues_df_filtered.columns]
venues_df_filtered.head()
# Out:
#                                                 name           categories  \
# 0  Los Angeles Mayor's Office of Economic Develop...  Government Building
# 1              James K. Hahn City Hall East Building            City Hall
# 2                           Los Angeles Civic Center  Government Building
# 3                              Los Angeles City Hall            City Hall
# 4                      Office of Mayor Eric Garcetti            City Hall
#
#                  address  cc         city        country    crossStreet  \
# 0                    NaN  US  Los Angeles  United States            NaN
# 1          200 N Main St  US  Los Angeles  United States  Temple Street
# 2        200 N Spring St  US  Los Angeles  United States            NaN
# 3        200 N Spring St  US  Los Angeles  United States  at Temple Ave
# 4  Los Angeles City Hall  US  Los Angeles  United States            NaN
#
#    distance                                   formattedAddress  \
# 0        38                   [Los Angeles, CA, United States]
# 1       112  [200 N Main St (Temple Street), Los Angeles, C...
# 2        60  [200 N Spring St, Los Angeles, CA 90012, Unite...
# 3        35  [200 N Spring St (at Temple Ave), Los Angeles,...
# 4        45  [Los Angeles City Hall, Los Angeles, CA 90012,...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 34.05378746696942...  34.053787 -118.242369
# 1  [{'label': 'display', 'lat': 34.05301072481605...  34.053011 -118.241863
# 2  [{'label': 'display', 'lat': 34.05415339478075...  34.054153 -118.243117
# 3  [{'label': 'display', 'lat': 34.05348417688625...  34.053484 -118.242478
# 4  [{'label': 'display', 'lat': 34.05393149240509...  34.053931 -118.243169
#
#    neighborhood postalCode state                        id
# 0           NaN        NaN    CA  52ebf057498ee83c88d9c1f9
# 1           NaN      90012    CA  4b38d6b3f964a520fb5025e3
# 2           NaN      90012    CA  4d65fb1dc2ccb60ca24c6bac
# 3  Civic Center      90012    CA  4b5113edf964a520314127e3
# 4           NaN      90012    CA  4d9ccfabc593a1cd8dff5119

# %%
# Check the size
venues_df_filtered.shape
# Out:
# (100, 16)

# %%
# Nearby venues function
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        #print(lat)
        #print(lng)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lng, 
            lat, 
            radius, 
            LIMIT)
            
        #print(url)
        
        # make the GET request
        #results = requests.get(url).json()["response"]['groups'][0]['items']
        results = requests.get(url).json()['response'].get('groups',[{}])[0].get('items', [])
        
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
names=la_neighborhood_df['name']

# %%
# The neighborhood that have venues in La
la_venues = getNearbyVenues(names=names,
                                   latitudes=rslt_df['latitude'],
                                   longitudes=rslt_df['longitude']
                                  )
# Out:
# Acton
# Adams-Normandie
# Agoura Hills
# Agua Dulce
# Alhambra
# Alondra Park
# Artesia
# Altadena
# Angeles Crest
# Arcadia
# Arleta
# Arlington Heights
# Athens
# Atwater Village
# Avalon
# Avocado Heights
# Azusa
# Vermont-Slauson
# Baldwin Hills/Crenshaw
# Baldwin Park
# Bel-Air
# Bellflower
# Bell Gardens
# Green Valley
# Bell
# Beverly Crest
# Beverly Grove
# Burbank
# Koreatown
# Beverly Hills
# Beverlywood
# Boyle Heights
# Bradbury
# Brentwood
# Broadway-Manchester
# Calabasas
# Canoga Park
# Carson
# Carthay
# Castaic Canyons
# Chatsworth
# Castaic
# Central-Alameda
# Century City
# Cerritos
# Charter Oak
# Chatsworth Reservoir
# Chesterfield Square
# Cheviot Hills
# Chinatown
# Citrus
# Claremont
# Northridge
# Commerce
# Compton
# Cypress Park
# La Mirada
# Covina
# Cudahy
# Culver City
# Del Aire
# Del Rey
# Desert View Highlands
# Diamond Bar
# Downey
# Downtown
# Duarte
# Eagle Rock
# East Compton
# East Hollywood
# East La Mirada
# Elizabeth Lake
# East Los Angeles
# East Pasadena
# East San Gabriel
# Echo Park
# El Monte
# El Segundo
# El Sereno
# Elysian Park
# Elysian Valley
# Vermont Square
# Encino
# Exposition Park
# Fairfax
# Florence-Firestone
# Florence
# Gardena
# Glassell Park
# Green Meadows
# Vermont Vista
# Glendale
# Glendora
# Gramercy Park
# Granada Hills
# Griffith Park
# Hacienda Heights
# Hancock Park
# Hansen Dam
# Harbor City
# Harbor Gateway
# Harvard Heights
# Harvard Park
# Walnut Park
# Hasley Canyon
# Hawaiian Gardens
# Hawthorne
# Hermosa Beach
# Hidden Hills
# Mar Vista
# Highland Park
# Historic South-Central
# Hollywood Hills
# Hollywood Hills West
# Hollywood
# Huntington Park
# Hyde Park
# Inglewood
# Irwindale
# Jefferson Park
# Industry
# La Canada Flintridge
# La Crescenta-Montrose
# Ladera Heights
# Playa Vista
# La Habra Heights
# Lake Balboa
# Lake Hughes
# Lake Los Angeles
# Lake View Terrace
# Lakewood
# Lancaster
# La Puente
# Larchmont
# Watts
# La Verne
# Lawndale
# Leimert Park
# Lennox
# Leona Valley
# Lincoln Heights
# Littlerock
# Lomita
# Long Beach
# Lopez/Kagel Canyons
# Los Feliz
# Lynwood
# Malibu
# Manchester Square
# Manhattan Beach
# Marina del Rey
# Mayflower Village
# Maywood
# Mid-City
# Mid-Wilshire
# Mission Hills
# Monterey Park
# West Adams
# Monrovia
# Montebello
# Montecito Heights
# Mount Washington
# Northeast Antelope Valley
# North El Monte
# North Hills
# North Hollywood
# Northwest Antelope Valley
# Northwest Palmdale
# North Whittier
# Norwalk
# Pacific Palisades
# Pacoima
# Palos Verdes Estates
# Panorama City
# Palmdale
# Palms
# West Carson
# Paramount
# Pico Rivera
# Pico-Robertson
# Pico-Union
# Playa del Rey
# Pasadena
# Pomona
# Porter Ranch
# Quartz Hill
# Redondo Beach
# Ramona
# Rancho Dominguez
# Reseda
# Rolling Hills Estates
# Rancho Palos Verdes
# Rancho Park
# Ridge Route
# Rolling Hills
# Rosemead
# Rowland Heights
# Santa Fe Springs
# San Dimas

# %%
la_venues
# Out:
#           Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0                Acton            -118.300208               34.031461
# 1                Acton            -118.300208               34.031461
# 2                Acton            -118.300208               34.031461
# 3                Acton            -118.300208               34.031461
# 4                Acton            -118.300208               34.031461
# 5                Acton            -118.300208               34.031461
# 6                Acton            -118.300208               34.031461
# 7                Acton            -118.300208               34.031461
# 8                Acton            -118.300208               34.031461
# 9                Acton            -118.300208               34.031461
# 10               Acton            -118.300208               34.031461
# 11     Adams-Normandie            -118.759884               34.146736
# 12     Adams-Normandie            -118.759884               34.146736
# 13     Adams-Normandie            -118.759884               34.146736
# 14     Adams-Normandie            -118.759884               34.146736
# 15     Adams-Normandie            -118.759884               34.146736
# 16     Adams-Normandie            -118.759884               34.146736
# 17     Adams-Normandie            -118.759884               34.146736
# 18     Adams-Normandie            -118.759884               34.146736
# 19     Adams-Normandie            -118.759884               34.146736
# 20     Adams-Normandie            -118.759884               34.146736
# 21     Adams-Normandie            -118.759884               34.146736
# 22     Adams-Normandie            -118.759884               34.146736
# 23     Adams-Normandie            -118.759884               34.146736
# 24     Adams-Normandie            -118.759884               34.146736
# 25     Adams-Normandie            -118.759884               34.146736
# 26     Adams-Normandie            -118.759884               34.146736
# 27     Adams-Normandie            -118.759884               34.146736
# 28     Adams-Normandie            -118.759884               34.146736
# 29     Adams-Normandie            -118.759884               34.146736
# ...                ...                    ...                     ...
# 2525          Rosemead            -118.259187               33.791294
# 2526          Rosemead            -118.259187               33.791294
# 2527          Rosemead            -118.259187               33.791294
# 2528   Rowland Heights            -118.319909               34.069108
# 2529   Rowland Heights            -118.319909               34.069108
# 2530   Rowland Heights            -118.319909               34.069108
# 2531   Rowland Heights            -118.319909               34.069108
# 2532   Rowland Heights            -118.319909               34.069108
# 2533  Santa Fe Springs            -118.575220               34.210459
# 2534  Santa Fe Springs            -118.575220               34.210459
# 2535  Santa Fe Springs            -118.575220               34.210459
# 2536  Santa Fe Springs            -118.575220               34.210459
# 2537  Santa Fe Springs            -118.575220               34.210459
# 2538  Santa Fe Springs            -118.575220               34.210459
# 2539  Santa Fe Springs            -118.575220               34.210459
# 2540  Santa Fe Springs            -118.575220               34.210459
# 2541  Santa Fe Springs            -118.575220               34.210459
# 2542  Santa Fe Springs            -118.575220               34.210459
# 2543  Santa Fe Springs            -118.575220               34.210459
# 2544  Santa Fe Springs            -118.575220               34.210459
# 2545  Santa Fe Springs            -118.575220               34.210459
# 2546  Santa Fe Springs            -118.575220               34.210459
# 2547  Santa Fe Springs            -118.575220               34.210459
# 2548  Santa Fe Springs            -118.575220               34.210459
# 2549  Santa Fe Springs            -118.575220               34.210459
# 2550  Santa Fe Springs            -118.575220               34.210459
# 2551         San Dimas            -118.615217               34.159409
# 2552         San Dimas            -118.615217               34.159409
# 2553         San Dimas            -118.615217               34.159409
# 2554         San Dimas            -118.615217               34.159409
#
#                                   Venue  Venue Latitude  Venue Longitude  \
# 0                              7-Eleven       34.033027      -118.299960
# 1                                 Shell       34.033095      -118.300025
# 2                           Little Xian       34.032292      -118.299465
# 3                         Sushi Delight       34.032501      -118.299454
# 4                     Tacos La Estrella       34.032230      -118.300757
# 5                   El Rincon Hondureño       34.032527      -118.298860
# 6                     Orange Door Sushi       34.032485      -118.299368
# 7        Loren Miller Recreational Park       34.031335      -118.303717
# 8                 Xtra Bionicos Allexis       34.032211      -118.296272
# 9                         Adlong market       34.032242      -118.296229
# 10               Richardson Family Park       34.028221      -118.297457
# 11                        El Pollo Loco       34.144732      -118.761088
# 12                           Sushi Raku       34.148230      -118.760163
# 13                         Trader Joe's       34.146241      -118.756609
# 14                          Urbane Cafe       34.146573      -118.758956
# 15                   Jinky's Kanan Cafe       34.146280      -118.756833
# 16              Boar Dough Tasting Room       34.144237      -118.756564
# 17                            Lal Mirch       34.147822      -118.760536
# 18               Wood Ranch BBQ & Grill       34.144711      -118.755350
# 19               The Habit Burger Grill       34.146674      -118.759053
# 20                   Islands Restaurant       34.143774      -118.762049
# 21                            Pizza Hut       34.147885      -118.760500
# 22        Ladyface Alehouse & Brasserie       34.143834      -118.762823
# 23                             Speedway       34.143928      -118.761142
# 24                                Shell       34.147185      -118.760667
# 25                          Exotic Thai       34.144164      -118.756991
# 26                 Agoura Liquor & Deli       34.144549      -118.762875
# 27     FedEx Office Print & Ship Center       34.144670      -118.755906
# 28                        Adobe Cantina       34.143010      -118.758330
# 29                   Padris Martini Bar       34.143198      -118.756827
# ...                                 ...             ...              ...
# 2525                                WSS       33.791666      -118.261219
# 2526           Taqueria El Taco Loco #4       33.790914      -118.261857
# 2527                       Pronto Pizza       33.790799      -118.264395
# 2528                         Dana Levee       34.070976      -118.317520
# 2529  Mac'D N Loaded - East Los Angeles       34.070998      -118.316677
# 2530       South Windsor Bl (B/W 4 & 5)       34.065946      -118.321433
# 2531                    Walking The Dog       34.066459      -118.316912
# 2532                                Gym       34.066045      -118.316719
# 2533                           7-Eleven       34.208902      -118.571308
# 2534                  Crazy Harry's Bar       34.208189      -118.571561
# 2535                     Johnny Pacific       34.208097      -118.570644
# 2536                     Baskin-Robbins       34.208739      -118.572644
# 2537         Jackson Hewitt Tax Service       34.208175      -118.571675
# 2538                       Kalesa Grill       34.208645      -118.572712
# 2539                        Food 4 Less       34.209158      -118.572611
# 2540                          Las Dunas       34.209303      -118.572029
# 2541                   Church's Chicken       34.209407      -118.571361
# 2542       Anything Electrical Services       34.209566      -118.574367
# 2543                    Valdez Plumbing       34.208715      -118.574409
# 2544                   Photo Editing HQ       34.208740      -118.574249
# 2545              Hubbard HVAC Services       34.212540      -118.573987
# 2546                       Rigo's Tacos       34.208017      -118.573128
# 2547                  Teriyaki Masudaya       34.209354      -118.571817
# 2548          Carl's Jr / Green Burrito       34.208568      -118.571805
# 2549                #1 Delicious Donuts       34.208923      -118.571622
# 2550                             Frutal       34.208124      -118.571606
# 2551                  e-Motion Training       34.158111      -118.615593
# 2552         Deats Stewart Deats Design       34.159030      -118.612447
# 2553                             F or D       34.158239      -118.618153
# 2554  Woodland Hills Carpet Restoration       34.158725      -118.618393
#
#                  Venue Category
# 0             Convenience Store
# 1                   Gas Station
# 2              Sushi Restaurant
# 3              Sushi Restaurant
# 4                    Taco Place
# 5     Latin American Restaurant
# 6              Sushi Restaurant
# 7                    Playground
# 8                  Dessert Shop
# 9                 Grocery Store
# 10                         Park
# 11         Fast Food Restaurant
# 12             Sushi Restaurant
# 13                Grocery Store
# 14                         Café
# 15               Breakfast Spot
# 16                   Restaurant
# 17            Indian Restaurant
# 18                    BBQ Joint
# 19                 Burger Joint
# 20          American Restaurant
# 21                  Pizza Place
# 22                      Brewery
# 23                  Gas Station
# 24                  Gas Station
# 25              Thai Restaurant
# 26                Deli / Bodega
# 27               Shipping Store
# 28           Mexican Restaurant
# 29                       Lounge
# ...                         ...
# 2525                 Shoe Store
# 2526         Mexican Restaurant
# 2527                Pizza Place
# 2528        Sporting Goods Shop
# 2529                 Food Truck
# 2530             Scenic Lookout
# 2531                    Dog Run
# 2532       Gym / Fitness Center
# 2533          Convenience Store
# 2534                        Bar
# 2535  Latin American Restaurant
# 2536             Ice Cream Shop
# 2537           Business Service
# 2538        Filipino Restaurant
# 2539              Grocery Store
# 2540  South American Restaurant
# 2541        Fried Chicken Joint
# 2542          Electronics Store
# 2543               Home Service
# 2544           Business Service
# 2545               Home Service
# 2546         Mexican Restaurant
# 2547        Japanese Restaurant
# 2548       Fast Food Restaurant
# 2549                 Donut Shop
# 2550    Fruit & Vegetable Store
# 2551       Gym / Fitness Center
# 2552                   Wine Bar
# 2553       Arts & Entertainment
# 2554               Carpet Store
#
# [2555 rows x 7 columns]

# %%
la_venues.groupby('Neighborhood').count()
# Out:
#                         Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Acton                                      11                      11     11
# Adams-Normandie                            29                      29     29
# Agoura Hills                               13                      13     13
# Agua Dulce                                 28                      28     28
# Alhambra                                   24                      24     24
# Alondra Park                                5                       5      5
# Altadena                                   20                      20     20
# Angeles Crest                               4                       4      4
# Arcadia                                    10                      10     10
# Arleta                                      6                       6      6
# Arlington Heights                           4                       4      4
# Artesia                                    28                      28     28
# Athens                                      7                       7      7
# Atwater Village                             3                       3      3
# Avalon                                     12                      12     12
# Avocado Heights                            12                      12     12
# Baldwin Hills/Crenshaw                    100                     100    100
# Baldwin Park                               15                      15     15
# Bel-Air                                    73                      73     73
# Bell                                        2                       2      2
# Bell Gardens                                5                       5      5
# Bellflower                                  2                       2      2
# Beverly Crest                               2                       2      2
# Beverly Grove                               5                       5      5
# Beverlywood                                14                      14     14
# Boyle Heights                               1                       1      1
# Bradbury                                    4                       4      4
# Brentwood                                  53                      53     53
# Broadway-Manchester                         3                       3      3
# Canoga Park                                 5                       5      5
# ...                                       ...                     ...    ...
# Palos Verdes Estates                       14                      14     14
# Panorama City                               2                       2      2
# Paramount                                  15                      15     15
# Pasadena                                   36                      36     36
# Pico Rivera                                53                      53     53
# Pico-Robertson                             30                      30     30
# Pico-Union                                 14                      14     14
# Playa Vista                                 3                       3      3
# Playa del Rey                              18                      18     18
# Pomona                                      4                       4      4
# Porter Ranch                                2                       2      2
# Quartz Hill                                 2                       2      2
# Ramona                                      6                       6      6
# Rancho Dominguez                            8                       8      8
# Rancho Palos Verdes                         8                       8      8
# Rancho Park                                31                      31     31
# Redondo Beach                              45                      45     45
# Reseda                                     55                      55     55
# Ridge Route                                25                      25     25
# Rolling Hills Estates                      10                      10     10
# Rosemead                                   10                      10     10
# Rowland Heights                             5                       5      5
# San Dimas                                   4                       4      4
# Santa Fe Springs                           18                      18     18
# Vermont Square                             29                      29     29
# Vermont Vista                              46                      46     46
# Walnut Park                                 3                       3      3
# Watts                                       4                       4      4
# West Adams                                 13                      13     13
# West Carson                                 4                       4      4
#
#                         Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Acton                               11               11              11
# Adams-Normandie                     29               29              29
# Agoura Hills                        13               13              13
# Agua Dulce                          28               28              28
# Alhambra                            24               24              24
# Alondra Park                         5                5               5
# Altadena                            20               20              20
# Angeles Crest                        4                4               4
# Arcadia                             10               10              10
# Arleta                               6                6               6
# Arlington Heights                    4                4               4
# Artesia                             28               28              28
# Athens                               7                7               7
# Atwater Village                      3                3               3
# Avalon                              12               12              12
# Avocado Heights                     12               12              12
# Baldwin Hills/Crenshaw             100              100             100
# Baldwin Park                        15               15              15
# Bel-Air                             73               73              73
# Bell                                 2                2               2
# Bell Gardens                         5                5               5
# Bellflower                           2                2               2
# Beverly Crest                        2                2               2
# Beverly Grove                        5                5               5
# Beverlywood                         14               14              14
# Boyle Heights                        1                1               1
# Bradbury                             4                4               4
# Brentwood                           53               53              53
# Broadway-Manchester                  3                3               3
# Canoga Park                          5                5               5
# ...                                ...              ...             ...
# Palos Verdes Estates                14               14              14
# Panorama City                        2                2               2
# Paramount                           15               15              15
# Pasadena                            36               36              36
# Pico Rivera                         53               53              53
# Pico-Robertson                      30               30              30
# Pico-Union                          14               14              14
# Playa Vista                          3                3               3
# Playa del Rey                       18               18              18
# Pomona                               4                4               4
# Porter Ranch                         2                2               2
# Quartz Hill                          2                2               2
# Ramona                               6                6               6
# Rancho Dominguez                     8                8               8
# Rancho Palos Verdes                  8                8               8
# Rancho Park                         31               31              31
# Redondo Beach                       45               45              45
# Reseda                              55               55              55
# Ridge Route                         25               25              25
# Rolling Hills Estates               10               10              10
# Rosemead                            10               10              10
# Rowland Heights                      5                5               5
# San Dimas                            4                4               4
# Santa Fe Springs                    18               18              18
# Vermont Square                      29               29              29
# Vermont Vista                       46               46              46
# Walnut Park                          3                3               3
# Watts                                4                4               4
# West Adams                          13               13              13
# West Carson                          4                4               4
#
# [185 rows x 6 columns]

# %%
print('Number of unique categories is {}.'.format(len(la_venues['Venue Category'].unique())))
# Out:
# Number of unique categories is 298.

# %% [markdown]
# Finally, filter out all venues that are not restaurants.

# %%
options = ['Fast Food Restaurant' ,'Breakfast Spot',
 'Café', 'Restaurant', 'Indian Restaurant', 'BBQ Joint' ,'Burger Joint',
 'American Restaurant', 'Pizza Place', 'Brewery' 'Thai Restaurant',
 'Deli / Bodega', 'Mexican Restaurant','Sushi Restaurant' , 'Taco Place',
 'Hawaiian Restaurant',
 'Taiwanese Restaurant', 'Vegetarian / Vegan Restaurant',
 'Vietnamese Restaurant' ,'Japanese Restaurant' ,
 'Korean Restaurant', 
 'Donburi Restaurant', 'Seafood Restaurant',  'Dumpling Restaurant',
 'Mediterranean Restaurant', 'Southern / Soul Food Restaurant' 'Diner',
 'Udon Restaurant', 'Empanada Restaurant', 'Ramen Restaurant' 'Cuban Restaurant',
 'Korean BBQ Restaurant', 'Hotel Bar', 'Brazilian Restaurant', 'Ethiopian Restaurant',
 'French Restaurant', 'Cajun / Creole Restaurant' ,'Filipino Restaurant',
 'Dim Sum Restaurant',  'Greek Restaurant' ,'Noodle House' , 'New American Restaurant',
 'Middle Eastern Restaurant', 'Falafel Restaurant',
 'Persian Restaurant', 'Caribbean Restaurant', 'Andhra Restaurant' ,
 'Russian Restaurant'
  ] 

# selecting rows based on condition 
la_rest_df = la_venues.loc[la_venues['Venue Category'].isin(options)] 
la_rest_df
# Out:
#                Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 2                     Acton            -118.300208               34.031461
# 3                     Acton            -118.300208               34.031461
# 4                     Acton            -118.300208               34.031461
# 6                     Acton            -118.300208               34.031461
# 11          Adams-Normandie            -118.759884               34.146736
# 12          Adams-Normandie            -118.759884               34.146736
# 14          Adams-Normandie            -118.759884               34.146736
# 15          Adams-Normandie            -118.759884               34.146736
# 16          Adams-Normandie            -118.759884               34.146736
# 17          Adams-Normandie            -118.759884               34.146736
# 18          Adams-Normandie            -118.759884               34.146736
# 19          Adams-Normandie            -118.759884               34.146736
# 20          Adams-Normandie            -118.759884               34.146736
# 21          Adams-Normandie            -118.759884               34.146736
# 26          Adams-Normandie            -118.759884               34.146736
# 28          Adams-Normandie            -118.759884               34.146736
# 33          Adams-Normandie            -118.759884               34.146736
# 34          Adams-Normandie            -118.759884               34.146736
# 36          Adams-Normandie            -118.759884               34.146736
# 37          Adams-Normandie            -118.759884               34.146736
# 39          Adams-Normandie            -118.759884               34.146736
# 41             Agoura Hills            -118.136512               34.085539
# 43             Agoura Hills            -118.136512               34.085539
# 48             Agoura Hills            -118.136512               34.085539
# 49             Agoura Hills            -118.136512               34.085539
# 53               Agua Dulce            -118.080101               33.866896
# 54               Agua Dulce            -118.080101               33.866896
# 56               Agua Dulce            -118.080101               33.866896
# 57               Agua Dulce            -118.080101               33.866896
# 59               Agua Dulce            -118.080101               33.866896
# ...                     ...                    ...                     ...
# 2448  Rolling Hills Estates            -118.272221               34.062361
# 2449  Rolling Hills Estates            -118.272221               34.062361
# 2455    Rancho Palos Verdes            -118.822912               34.139191
# 2456    Rancho Palos Verdes            -118.822912               34.139191
# 2462            Rancho Park            -118.430745               34.047221
# 2463            Rancho Park            -118.430745               34.047221
# 2465            Rancho Park            -118.430745               34.047221
# 2466            Rancho Park            -118.430745               34.047221
# 2467            Rancho Park            -118.430745               34.047221
# 2468            Rancho Park            -118.430745               34.047221
# 2469            Rancho Park            -118.430745               34.047221
# 2472            Rancho Park            -118.430745               34.047221
# 2474            Rancho Park            -118.430745               34.047221
# 2483            Rancho Park            -118.430745               34.047221
# 2489            Rancho Park            -118.430745               34.047221
# 2490            Rancho Park            -118.430745               34.047221
# 2498            Ridge Route            -118.440480               34.065235
# 2505            Ridge Route            -118.440480               34.065235
# 2513            Ridge Route            -118.440480               34.065235
# 2514            Ridge Route            -118.440480               34.065235
# 2515            Ridge Route            -118.440480               34.065235
# 2520               Rosemead            -118.259187               33.791294
# 2523               Rosemead            -118.259187               33.791294
# 2524               Rosemead            -118.259187               33.791294
# 2526               Rosemead            -118.259187               33.791294
# 2527               Rosemead            -118.259187               33.791294
# 2538       Santa Fe Springs            -118.575220               34.210459
# 2546       Santa Fe Springs            -118.575220               34.210459
# 2547       Santa Fe Springs            -118.575220               34.210459
# 2548       Santa Fe Springs            -118.575220               34.210459
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 2                       Little Xian       34.032292      -118.299465
# 3                     Sushi Delight       34.032501      -118.299454
# 4                 Tacos La Estrella       34.032230      -118.300757
# 6                 Orange Door Sushi       34.032485      -118.299368
# 11                    El Pollo Loco       34.144732      -118.761088
# 12                       Sushi Raku       34.148230      -118.760163
# 14                      Urbane Cafe       34.146573      -118.758956
# 15               Jinky's Kanan Cafe       34.146280      -118.756833
# 16          Boar Dough Tasting Room       34.144237      -118.756564
# 17                        Lal Mirch       34.147822      -118.760536
# 18           Wood Ranch BBQ & Grill       34.144711      -118.755350
# 19           The Habit Burger Grill       34.146674      -118.759053
# 20               Islands Restaurant       34.143774      -118.762049
# 21                        Pizza Hut       34.147885      -118.760500
# 26             Agoura Liquor & Deli       34.144549      -118.762875
# 28                    Adobe Cantina       34.143010      -118.758330
# 33                             IHOP       34.145057      -118.762326
# 34                      Burger King       34.145041      -118.760059
# 36                  Jack in the Box       34.144170      -118.761967
# 37                       McDonald's       34.147188      -118.760181
# 39                         Sushi Su       34.144230      -118.756564
# 41                   Domino's Pizza       34.083945      -118.134979
# 43                          Wendy’s       34.087705      -118.135010
# 48                    Manny's Tacos       34.087148      -118.135275
# 49                  Alhambra Donuts       34.083877      -118.134861
# 53          Paradise Biryani Pointe       33.865965      -118.081489
# 54             The India Restaurant       33.868712      -118.081972
# 56                    Surati Farsan       33.862842      -118.081796
# 57       Rajdhani Indian Restaurant       33.863290      -118.082436
# 59            Mumbai Ki Galliyon Se       33.870204      -118.082568
# ...                             ...             ...              ...
# 2448                Jack in the Box       34.058459      -118.273011
# 2449                  El Pollo Loco       34.060599      -118.274412
# 2455  The Landing Grill & Sushi Bar       34.138662      -118.823038
# 2456           Zin Bistro Americana       34.139325      -118.823601
# 2462        California Chicken Cafe       34.046434      -118.434128
# 2463                 Tacos Tu Madre       34.047562      -118.434983
# 2465                Taste of Tehran       34.047817      -118.435161
# 2466               That Pizza Place       34.044471      -118.431819
# 2467                  Pitfire Pizza       34.046502      -118.433880
# 2468                    Poquito Mas       34.043239      -118.431712
# 2469                          Necco       34.047640      -118.435004
# 2472                   Zuma Kitchen       34.047611      -118.434759
# 2474               California Fresh       34.046700      -118.434024
# 2483             The Room Sushi Bar       34.048453      -118.435527
# 2489          India's Oven Westwood       34.048366      -118.435465
# 2490                     Farsi Cafe       34.047947      -118.434953
# 2498                    Blaze Pizza       34.068379      -118.442360
# 2505                    Chick-fil-A       34.063509      -118.445144
# 2513                  UCLA Cafe Med       34.066094      -118.443508
# 2514                      SEAS Café       34.068954      -118.442963
# 2515                      Yoshinoya       34.068160      -118.442338
# 2520                 Domino's Pizza       33.790648      -118.262836
# 2523                  El Pollo Loco       33.790963      -118.263056
# 2524                      Taco Bell       33.790980      -118.263598
# 2526       Taqueria El Taco Loco #4       33.790914      -118.261857
# 2527                   Pronto Pizza       33.790799      -118.264395
# 2538                   Kalesa Grill       34.208645      -118.572712
# 2546                   Rigo's Tacos       34.208017      -118.573128
# 2547              Teriyaki Masudaya       34.209354      -118.571817
# 2548      Carl's Jr / Green Burrito       34.208568      -118.571805
#
#                 Venue Category
# 2             Sushi Restaurant
# 3             Sushi Restaurant
# 4                   Taco Place
# 6             Sushi Restaurant
# 11        Fast Food Restaurant
# 12            Sushi Restaurant
# 14                        Café
# 15              Breakfast Spot
# 16                  Restaurant
# 17           Indian Restaurant
# 18                   BBQ Joint
# 19                Burger Joint
# 20         American Restaurant
# 21                 Pizza Place
# 26               Deli / Bodega
# 28          Mexican Restaurant
# 33              Breakfast Spot
# 34        Fast Food Restaurant
# 36        Fast Food Restaurant
# 37        Fast Food Restaurant
# 39            Sushi Restaurant
# 41                 Pizza Place
# 43        Fast Food Restaurant
# 48          Mexican Restaurant
# 49              Breakfast Spot
# 53           Indian Restaurant
# 54           Indian Restaurant
# 56           Indian Restaurant
# 57           Indian Restaurant
# 59           Indian Restaurant
# ...                        ...
# 2448      Fast Food Restaurant
# 2449      Fast Food Restaurant
# 2455          Sushi Restaurant
# 2456       American Restaurant
# 2462       American Restaurant
# 2463                Taco Place
# 2465        Persian Restaurant
# 2466               Pizza Place
# 2467               Pizza Place
# 2468        Mexican Restaurant
# 2469       Japanese Restaurant
# 2472  Mediterranean Restaurant
# 2474  Mediterranean Restaurant
# 2483          Sushi Restaurant
# 2489         Indian Restaurant
# 2490        Persian Restaurant
# 2498               Pizza Place
# 2505      Fast Food Restaurant
# 2513                      Café
# 2514                      Café
# 2515        Donburi Restaurant
# 2520               Pizza Place
# 2523      Fast Food Restaurant
# 2524      Fast Food Restaurant
# 2526        Mexican Restaurant
# 2527               Pizza Place
# 2538       Filipino Restaurant
# 2546        Mexican Restaurant
# 2547       Japanese Restaurant
# 2548      Fast Food Restaurant
#
# [717 rows x 7 columns]

# %% [markdown]
# We now have two datasets, one, the neightborhoods, the other, restaurants. We will combine and use these datasets to perform analysis.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# The approach used is KMeans clustering. Restaurants will be clustered around the neightborhoods and neighborhoods without clusters will be analyzed.
#
# First, start with the onehot encoding.

# %%
# Onehot encoding
la_onehot = pd.get_dummies(la_rest_df[['Venue Category']], prefix="", prefix_sep="")
la_onehot['Neighborhood'] = la_rest_df['Neighborhood'] 
fixed_columns = [la_onehot.columns[-1]] + list(la_onehot.columns[:-1])
final_onehot = la_onehot[fixed_columns]

# %%
final_onehot.head()
# Out:
#        Neighborhood  American Restaurant  Andhra Restaurant  BBQ Joint  \
# 2             Acton                    0                  0          0
# 3             Acton                    0                  0          0
# 4             Acton                    0                  0          0
# 6             Acton                    0                  0          0
# 11  Adams-Normandie                    0                  0          0
#
#     Brazilian Restaurant  Breakfast Spot  Burger Joint  Café  \
# 2                      0               0             0     0
# 3                      0               0             0     0
# 4                      0               0             0     0
# 6                      0               0             0     0
# 11                     0               0             0     0
#
#     Cajun / Creole Restaurant  Caribbean Restaurant  ...  Pizza Place  \
# 2                           0                     0  ...            0
# 3                           0                     0  ...            0
# 4                           0                     0  ...            0
# 6                           0                     0  ...            0
# 11                          0                     0  ...            0
#
#     Restaurant  Russian Restaurant  Seafood Restaurant  Sushi Restaurant  \
# 2            0                   0                   0                 1
# 3            0                   0                   0                 1
# 4            0                   0                   0                 0
# 6            0                   0                   0                 1
# 11           0                   0                   0                 0
#
#     Taco Place  Taiwanese Restaurant  Udon Restaurant  \
# 2            0                     0                0
# 3            0                     0                0
# 4            1                     0                0
# 6            0                     0                0
# 11           0                     0                0
#
#     Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 2                               0                      0
# 3                               0                      0
# 4                               0                      0
# 6                               0                      0
# 11                              0                      0
#
# [5 rows x 43 columns]

# %%
final_onehot.shape
# Out:
# (717, 43)

# %% [markdown]
# Explore the data a bit more.

# %%
# Group by neighborhood
la_df_grouped = final_onehot.groupby('Neighborhood').mean().reset_index()
la_df_grouped.head()
# Out:
#       Neighborhood  American Restaurant  Andhra Restaurant  BBQ Joint  \
# 0            Acton             0.000000                0.0   0.000000
# 1  Adams-Normandie             0.058824                0.0   0.058824
# 2     Agoura Hills             0.000000                0.0   0.000000
# 3       Agua Dulce             0.000000                0.0   0.071429
# 4         Alhambra             0.000000                0.0   0.000000
#
#    Brazilian Restaurant  Breakfast Spot  Burger Joint      Café  \
# 0                   0.0        0.000000      0.000000  0.000000
# 1                   0.0        0.117647      0.058824  0.058824
# 2                   0.0        0.250000      0.000000  0.000000
# 3                   0.0        0.000000      0.000000  0.000000
# 4                   0.0        0.000000      0.000000  0.000000
#
#    Cajun / Creole Restaurant  Caribbean Restaurant  ...  Pizza Place  \
# 0                        0.0                   0.0  ...     0.000000
# 1                        0.0                   0.0  ...     0.058824
# 2                        0.0                   0.0  ...     0.250000
# 3                        0.0                   0.0  ...     0.071429
# 4                        0.0                   0.0  ...     0.250000
#
#    Restaurant  Russian Restaurant  Seafood Restaurant  Sushi Restaurant  \
# 0    0.000000                 0.0                 0.0          0.750000
# 1    0.058824                 0.0                 0.0          0.117647
# 2    0.000000                 0.0                 0.0          0.000000
# 3    0.000000                 0.0                 0.0          0.000000
# 4    0.000000                 0.0                 0.0          0.000000
#
#    Taco Place  Taiwanese Restaurant  Udon Restaurant  \
# 0        0.25              0.000000              0.0
# 1        0.00              0.000000              0.0
# 2        0.00              0.000000              0.0
# 3        0.00              0.071429              0.0
# 4        0.00              0.000000              0.0
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0                       0.000000               0.000000
# 1                       0.000000               0.000000
# 2                       0.000000               0.000000
# 3                       0.071429               0.142857
# 4                       0.000000               0.000000
#
# [5 rows x 43 columns]

# %%
num_top_venues = 3

for hood in la_df_grouped['Neighborhood']:
    print("------- "+hood+" -------")
    temp = la_df_grouped[la_df_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ------- Acton -------
#                  venue  freq
# 0     Sushi Restaurant  0.75
# 1           Taco Place  0.25
# 2  American Restaurant  0.00
#
#
# ------- Adams-Normandie -------
#                   venue  freq
# 0  Fast Food Restaurant  0.24
# 1        Breakfast Spot  0.12
# 2      Sushi Restaurant  0.12
#
#
# ------- Agoura Hills -------
#                 venue  freq
# 0         Pizza Place  0.25
# 1      Breakfast Spot  0.25
# 2  Mexican Restaurant  0.25
#
#
# ------- Agua Dulce -------
#                    venue  freq
# 0      Indian Restaurant  0.50
# 1  Vietnamese Restaurant  0.14
# 2   Taiwanese Restaurant  0.07
#
#
# ------- Alhambra -------
#                   venue  freq
# 0           Pizza Place  0.25
# 1    Mexican Restaurant  0.25
# 2  Fast Food Restaurant  0.25
#
#
# ------- Altadena -------
#                   venue  freq
# 0            Taco Place   0.4
# 1           Pizza Place   0.2
# 2  Fast Food Restaurant   0.2
#
#
# ------- Angeles Crest -------
#                  venue  freq
# 0  American Restaurant   0.5
# 1   Mexican Restaurant   0.5
# 2   Persian Restaurant   0.0
#
#
# ------- Arcadia -------
#                  venue  freq
# 0          Pizza Place   1.0
# 1   Persian Restaurant   0.0
# 2  Japanese Restaurant   0.0
#
#
# ------- Arleta -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Artesia -------
#                            venue  freq
# 0              Korean Restaurant  0.33
# 1  Vegetarian / Vegan Restaurant  0.22
# 2                     Taco Place  0.11
#
#
# ------- Athens -------
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Avalon -------
#                 venue  freq
# 0         Pizza Place  0.50
# 1        Burger Joint  0.25
# 2  Mexican Restaurant  0.25
#
#
# ------- Avocado Heights -------
#                   venue  freq
# 0          Burger Joint   0.4
# 1    Mexican Restaurant   0.2
# 2  Fast Food Restaurant   0.2
#
#
# ------- Baldwin Hills/Crenshaw -------
#                            venue  freq
# 0               Sushi Restaurant  0.14
# 1             Mexican Restaurant  0.14
# 2  Vegetarian / Vegan Restaurant  0.10
#
#
# ------- Baldwin Park -------
#                   venue  freq
# 0    Mexican Restaurant  0.50
# 1  Fast Food Restaurant  0.25
# 2         Deli / Bodega  0.25
#
#
# ------- Bel-Air -------
#                venue  freq
# 0  Korean Restaurant  0.45
# 1               Café  0.12
# 2          Hotel Bar  0.06
#
#
# ------- Bellflower -------
#                  venue  freq
# 0       Breakfast Spot   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Beverly Crest -------
#                  venue  freq
# 0                 Café   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Beverly Grove -------
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Beverlywood -------
#                   venue  freq
# 0  Ethiopian Restaurant  0.86
# 1                  Café  0.14
# 2   American Restaurant  0.00
#
#
# ------- Bradbury -------
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Brentwood -------
#                  venue  freq
# 0  American Restaurant  0.22
# 1   Mexican Restaurant  0.22
# 2           Restaurant  0.22
#
#
# ------- Broadway-Manchester -------
#                  venue  freq
# 0    Korean Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Canoga Park -------
#                       venue  freq
# 0  Mediterranean Restaurant  0.33
# 1              Burger Joint  0.33
# 2        Mexican Restaurant  0.33
#
#
# ------- Carthay -------
#                    venue  freq
# 0  Vietnamese Restaurant  0.46
# 1     Dim Sum Restaurant  0.15
# 2           Burger Joint  0.08
#
#
# ------- Central-Alameda -------
#                   venue  freq
# 0  Fast Food Restaurant  0.50
# 1           Pizza Place  0.25
# 2        Breakfast Spot  0.12
#
#
# ------- Century City -------
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Cerritos -------
#                   venue  freq
# 0  Fast Food Restaurant  0.33
# 1      Sushi Restaurant  0.33
# 2    Mexican Restaurant  0.33
#
#
# ------- Charter Oak -------
#                  venue  freq
# 0         Burger Joint   0.4
# 1  American Restaurant   0.2
# 2          Pizza Place   0.2
#
#
# ------- Chatsworth -------
#                   venue  freq
# 0           Pizza Place   0.5
# 1  Fast Food Restaurant   0.5
# 2    Persian Restaurant   0.0
#
#
# ------- Chatsworth Reservoir -------
#                   venue  freq
# 0  Fast Food Restaurant  0.33
# 1   American Restaurant  0.17
# 2          Burger Joint  0.17
#
#
# ------- Chesterfield Square -------
#               venue  freq
# 0       Pizza Place  0.14
# 1        Restaurant  0.14
# 2  Greek Restaurant  0.07
#
#
# ------- Cheviot Hills -------
#                            venue  freq
# 0             Mexican Restaurant  0.33
# 1  Vegetarian / Vegan Restaurant  0.17
# 2                     Taco Place  0.17
#
#
# ------- Chinatown -------
#                   venue  freq
# 0           Pizza Place  0.27
# 1  Fast Food Restaurant  0.18
# 2      Sushi Restaurant  0.18
#
#
# ------- Citrus -------
#                  venue  freq
# 0         Burger Joint  0.23
# 1  American Restaurant  0.15
# 2   Mexican Restaurant  0.15
#
#
# ------- Claremont -------
#                            venue  freq
# 0            American Restaurant  0.12
# 1  Vegetarian / Vegan Restaurant  0.12
# 2                 Breakfast Spot  0.12
#
#
# ------- Compton -------
#                       venue  freq
# 0               Pizza Place  0.11
# 1  Mediterranean Restaurant  0.11
# 2                Taco Place  0.11
#
#
# ------- Cudahy -------
#                    venue  freq
# 0  Vietnamese Restaurant  0.25
# 1     Seafood Restaurant  0.25
# 2             Restaurant  0.25
#
#
# ------- Cypress Park -------
#                 venue  freq
# 0  Mexican Restaurant  0.22
# 1                Café  0.17
# 2         Pizza Place  0.17
#
#
# ------- Del Aire -------
#                  venue  freq
# 0   Seafood Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Del Rey -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Desert View Highlands -------
#                  venue  freq
# 0  American Restaurant  0.25
# 1        Deli / Bodega  0.25
# 2  Japanese Restaurant  0.25
#
#
# ------- Downey -------
#                 venue  freq
# 0  Mexican Restaurant  0.50
# 1          Taco Place  0.17
# 2    Sushi Restaurant  0.17
#
#
# ------- Downtown -------
#                   venue  freq
# 0   American Restaurant  0.25
# 1    Mexican Restaurant  0.25
# 2  Fast Food Restaurant  0.25
#
#
# ------- Duarte -------
#                    venue  freq
# 0    Japanese Restaurant  0.24
# 1           Noodle House  0.14
# 2  Vietnamese Restaurant  0.10
#
#
# ------- Eagle Rock -------
#                  venue  freq
# 0                 Café  0.67
# 1           Taco Place  0.33
# 2  American Restaurant  0.00
#
#
# ------- East Compton -------
#                 venue  freq
# 0         Pizza Place   0.5
# 1  Seafood Restaurant   0.5
# 2  Persian Restaurant   0.0
#
#
# ------- East Hollywood -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- East Los Angeles -------
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1   American Restaurant   0.0
# 2    Persian Restaurant   0.0
#
#
# ------- East San Gabriel -------
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1   American Restaurant   0.0
# 2    Persian Restaurant   0.0
#
#
# ------- El Segundo -------
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Elysian Park -------
#                   venue  freq
# 0  Fast Food Restaurant  0.43
# 1           Pizza Place  0.14
# 2     Korean Restaurant  0.14
#
#
# ------- Elysian Valley -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Encino -------
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1           Pizza Place   0.2
# 2            Taco Place   0.2
#
#
# ------- Exposition Park -------
#                  venue  freq
# 0   Mexican Restaurant  0.15
# 1  American Restaurant  0.12
# 2           Restaurant  0.12
#
#
# ------- Florence -------
#                 venue  freq
# 0  Mexican Restaurant  0.27
# 1         Pizza Place  0.20
# 2                Café  0.20
#
#
# ------- Florence-Firestone -------
#                  venue  freq
# 0          Pizza Place   0.5
# 1                 Café   0.5
# 2  American Restaurant   0.0
#
#
# ------- Gardena -------
#                   venue  freq
# 0           Pizza Place  0.25
# 1  Fast Food Restaurant  0.25
# 2    Mexican Restaurant  0.25
#
#
# ------- Glendale -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Glendora -------
#                   venue  freq
# 0  Caribbean Restaurant   1.0
# 1   American Restaurant   0.0
# 2           Pizza Place   0.0
#
#
# ------- Gramercy Park -------
#                        venue  freq
# 0               Burger Joint  0.33
# 1  Cajun / Creole Restaurant  0.33
# 2       Caribbean Restaurant  0.33
#
#
# ------- Green Meadows -------
#                  venue  freq
# 0                 Café   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Green Valley -------
#                   venue  freq
# 0   Japanese Restaurant  0.33
# 1                  Café  0.33
# 2  Fast Food Restaurant  0.33
#
#
# ------- Griffith Park -------
#                  venue  freq
# 0           Taco Place   0.5
# 1   Mexican Restaurant   0.5
# 2  American Restaurant   0.0
#
#
# ------- Hansen Dam -------
#                  venue  freq
# 0  American Restaurant  0.12
# 1  Dumpling Restaurant  0.12
# 2  Hawaiian Restaurant  0.12
#
#
# ------- Harbor Gateway -------
#                   venue  freq
# 0  Fast Food Restaurant  0.33
# 1    Mexican Restaurant  0.33
# 2    Seafood Restaurant  0.33
#
#
# ------- Harvard Park -------
#                      venue  freq
# 0     Fast Food Restaurant   0.6
# 1      Japanese Restaurant   0.2
# 2  New American Restaurant   0.2
#
#
# ------- Hasley Canyon -------
#                   venue  freq
# 0  Fast Food Restaurant   0.5
# 1    Seafood Restaurant   0.5
# 2   American Restaurant   0.0
#
#
# ------- Hawaiian Gardens -------
#                  venue  freq
# 0  American Restaurant  0.33
# 1    Korean Restaurant  0.33
# 2   Mexican Restaurant  0.33
#
#
# ------- Hawthorne -------
#                   venue  freq
# 0                  Café   0.5
# 1  Fast Food Restaurant   0.5
# 2   American Restaurant   0.0
#
#
# ------- Hidden Hills -------
#                   venue  freq
# 0    Mexican Restaurant  0.38
# 1   American Restaurant  0.12
# 2  Fast Food Restaurant  0.12
#
#
# ------- Highland Park -------
#                   venue  freq
# 0    Mexican Restaurant  0.50
# 1  Fast Food Restaurant  0.33
# 2           Pizza Place  0.17
#
#
# ------- Historic South-Central -------
#                  venue  freq
# 0  Japanese Restaurant  0.33
# 1          Pizza Place  0.33
# 2         Burger Joint  0.33
#
#
# ------- Hollywood Hills -------
#                  venue  freq
# 0        Deli / Bodega   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Hollywood Hills West -------
#                       venue  freq
# 0  Mediterranean Restaurant  0.20
# 1          Greek Restaurant  0.13
# 2        Mexican Restaurant  0.13
#
#
# ------- Hyde Park -------
#                  venue  freq
# 0          Pizza Place   0.5
# 1         Burger Joint   0.5
# 2  American Restaurant   0.0
#
#
# ------- Industry -------
#                  venue  freq
# 0   Mexican Restaurant  0.15
# 1  American Restaurant  0.08
# 2    Korean Restaurant  0.08
#
#
# ------- Irwindale -------
#                   venue  freq
# 0    Mexican Restaurant  0.38
# 1           Pizza Place  0.25
# 2  Fast Food Restaurant  0.25
#
#
# ------- Jefferson Park -------
#                  venue  freq
# 0           Taco Place   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Koreatown -------
#                 venue  freq
# 0  Mexican Restaurant  0.50
# 1    Sushi Restaurant  0.25
# 2          Restaurant  0.25
#
#
# ------- La Habra Heights -------
#                  venue  freq
# 0   Mexican Restaurant  0.29
# 1  American Restaurant  0.14
# 2         Burger Joint  0.14
#
#
# ------- La Mirada -------
#           venue  freq
# 0    Restaurant   0.5
# 1  Burger Joint   0.5
# 2   Pizza Place   0.0
#
#
# ------- La Puente -------
#                  venue  freq
# 0       Breakfast Spot   0.5
# 1   Seafood Restaurant   0.5
# 2  American Restaurant   0.0
#
#
# ------- Ladera Heights -------
#                   venue  freq
# 0    Mexican Restaurant   0.4
# 1           Pizza Place   0.2
# 2  Fast Food Restaurant   0.2
#
#
# ------- Lake Los Angeles -------
#                   venue  freq
# 0           Pizza Place   0.5
# 1  Fast Food Restaurant   0.5
# 2    Persian Restaurant   0.0
#
#
# ------- Lake View Terrace -------
#                   venue  freq
# 0  Fast Food Restaurant  0.33
# 1           Pizza Place  0.17
# 2             BBQ Joint  0.17
#
#
# ------- Lakewood -------
#                  venue  freq
# 0  American Restaurant  0.25
# 1         Burger Joint  0.25
# 2           Taco Place  0.25
#
#
# ------- Lawndale -------
#                  venue  freq
# 0                 Café   0.4
# 1  Japanese Restaurant   0.2
# 2         Burger Joint   0.2
#
#
# ------- Leimert Park -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Leona Valley -------
#                  venue  freq
# 0     Sushi Restaurant  0.25
# 1          Pizza Place  0.17
# 2  American Restaurant  0.08
#
#
# ------- Lincoln Heights -------
#                   venue  freq
# 0  Fast Food Restaurant  0.33
# 1    Mexican Restaurant  0.33
# 2           Pizza Place  0.17
#
#
# ------- Lomita -------
#                   venue  freq
# 0           Pizza Place  0.33
# 1          Burger Joint  0.33
# 2  Fast Food Restaurant  0.33
#
#
# ------- Long Beach -------
#                  venue  freq
# 0           Taco Place   0.5
# 1   Mexican Restaurant   0.5
# 2  American Restaurant   0.0
#
#
# ------- Los Feliz -------
#                  venue  freq
# 0          Pizza Place   0.5
# 1  Japanese Restaurant   0.5
# 2   Persian Restaurant   0.0
#
#
# ------- Lynwood -------
#                    venue  freq
# 0  Vietnamese Restaurant  0.67
# 1   Fast Food Restaurant  0.33
# 2     Persian Restaurant  0.00
#
#
# ------- Manhattan Beach -------
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- Mayflower Village -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Mid-City -------
#                  venue  freq
# 0                 Café   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Mid-Wilshire -------
#                 venue  freq
# 0         Pizza Place  0.50
# 1      Breakfast Spot  0.25
# 2  Mexican Restaurant  0.25
#
#
# ------- Mission Hills -------
#                      venue  freq
# 0               Taco Place   0.5
# 1  New American Restaurant   0.5
# 2      American Restaurant   0.0
#
#
# ------- Montecito Heights -------
#                 venue  freq
# 0        Burger Joint  0.33
# 1                Café  0.33
# 2  Mexican Restaurant  0.33
#
#
# ------- Monterey Park -------
#               venue  freq
# 0  Greek Restaurant  0.33
# 1      Burger Joint  0.33
# 2        Taco Place  0.33
#
#
# ------- North El Monte -------
#                  venue  freq
# 0  American Restaurant  0.17
# 1       Breakfast Spot  0.17
# 2         Burger Joint  0.17
#
#
# ------- North Hollywood -------
#                   venue  freq
# 0   American Restaurant  0.17
# 1          Burger Joint  0.17
# 2  Fast Food Restaurant  0.17
#
#
# ------- Pacific Palisades -------
#                venue  freq
# 0        Pizza Place  0.25
# 1  French Restaurant  0.25
# 2         Restaurant  0.12
#
#
# ------- Pacoima -------
#                 venue  freq
# 0         Pizza Place  0.50
# 1  Mexican Restaurant  0.33
# 2  Seafood Restaurant  0.17
#
#
# ------- Palmdale -------
#                  venue  freq
# 0           Taco Place   0.5
# 1   Seafood Restaurant   0.5
# 2  American Restaurant   0.0
#
#
# ------- Palos Verdes Estates -------
#                  venue  freq
# 0  American Restaurant  0.17
# 1       Breakfast Spot  0.17
# 2   Mexican Restaurant  0.17
#
#
# ------- Paramount -------
#                  venue  freq
# 0       Breakfast Spot   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Pasadena -------
#                venue  freq
# 0         Restaurant  0.25
# 1  French Restaurant  0.12
# 2               Café  0.12
#
#
# ------- Pico Rivera -------
#                      venue  freq
# 0       Mexican Restaurant  0.23
# 1  New American Restaurant  0.15
# 2      American Restaurant  0.08
#
#
# ------- Pico-Robertson -------
#                   venue  freq
# 0           Pizza Place  0.25
# 1  Fast Food Restaurant  0.25
# 2    Mexican Restaurant  0.17
#
#
# ------- Pico-Union -------
#                 venue  freq
# 0         Pizza Place   0.5
# 1    Sushi Restaurant   0.5
# 2  Persian Restaurant   0.0
#
#
# ------- Playa del Rey -------
#                      venue  freq
# 0              Pizza Place  0.33
# 1       Mexican Restaurant  0.33
# 2  New American Restaurant  0.33
#
#
# ------- Pomona -------
#                  venue  freq
# 0         Burger Joint   1.0
# 1  American Restaurant   0.0
# 2          Pizza Place   0.0
#
#
# ------- Ramona -------
#                  venue  freq
# 0  Japanese Restaurant  0.33
# 1         Noodle House  0.33
# 2  Dumpling Restaurant  0.33
#
#
# ------- Rancho Palos Verdes -------
#                  venue  freq
# 0  American Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2   Persian Restaurant   0.0
#
#
# ------- Rancho Park -------
#                       venue  freq
# 0               Pizza Place  0.17
# 1  Mediterranean Restaurant  0.17
# 2        Persian Restaurant  0.17
#
#
# ------- Redondo Beach -------
#                   venue  freq
# 0           Pizza Place  0.38
# 1  Fast Food Restaurant  0.12
# 2     Korean Restaurant  0.12
#
#
# ------- Reseda -------
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant  0.16
# 1             Mexican Restaurant  0.16
# 2            American Restaurant  0.11
#
#
# ------- Ridge Route -------
#                 venue  freq
# 0                Café   0.4
# 1  Donburi Restaurant   0.2
# 2         Pizza Place   0.2
#
#
# ------- Rolling Hills Estates -------
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1   American Restaurant   0.0
# 2    Persian Restaurant   0.0
#
#
# ------- Rosemead -------
#                   venue  freq
# 0           Pizza Place   0.4
# 1  Fast Food Restaurant   0.4
# 2    Mexican Restaurant   0.2
#
#
# ------- Santa Fe Springs -------
#                   venue  freq
# 0   Japanese Restaurant  0.25
# 1   Filipino Restaurant  0.25
# 2  Fast Food Restaurant  0.25
#
#
# ------- Vermont Square -------
#                 venue  freq
# 0  Mexican Restaurant   0.5
# 1         Pizza Place   0.1
# 2  Persian Restaurant   0.1
#
#
# ------- Vermont Vista -------
#                       venue  freq
# 0          Sushi Restaurant  0.22
# 1       American Restaurant  0.11
# 2  Mediterranean Restaurant  0.11
#
#
# ------- Watts -------
#                  venue  freq
# 0   Mexican Restaurant   1.0
# 1  American Restaurant   0.0
# 2   Persian Restaurant   0.0
#
#
# ------- West Adams -------
#                  venue  freq
# 0  American Restaurant  0.33
# 1  Japanese Restaurant  0.33
# 2   Mexican Restaurant  0.33

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np

num_top_venues = 3

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = la_df_grouped['Neighborhood']

for ind in np.arange(la_df_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(la_df_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#       Neighborhood 1st Most Common Venue  2nd Most Common Venue  \
# 0            Acton      Sushi Restaurant             Taco Place
# 1  Adams-Normandie  Fast Food Restaurant       Sushi Restaurant
# 2     Agoura Hills  Fast Food Restaurant         Breakfast Spot
# 3       Agua Dulce     Indian Restaurant  Vietnamese Restaurant
# 4         Alhambra  Fast Food Restaurant    Japanese Restaurant
#
#            3rd Most Common Venue
# 0          Vietnamese Restaurant
# 1                 Breakfast Spot
# 2                    Pizza Place
# 3  Vegetarian / Vegan Restaurant
# 4             Mexican Restaurant

# %% [markdown]
# #### Clustering

# %%
from sklearn.cluster import KMeans

# Run Kmeans clustering and row labels
kclusters_num = 3
la_df_grouped_clustering = la_df_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters_num, random_state=0).fit(la_df_grouped_clustering)
kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 0, 2, 1, 2])

# %%
# Clustering Labels - only once
#neighborhoods_venues_sorted.insert(0, 'ClusterLabels', kmeans.labels_)
neighborhoods_venues_sorted.head()
# Out:
#    ClusterLabels     Neighborhood 1st Most Common Venue  \
# 0              2            Acton      Sushi Restaurant
# 1              2  Adams-Normandie  Fast Food Restaurant
# 2              2     Agoura Hills  Fast Food Restaurant
# 3              2       Agua Dulce     Indian Restaurant
# 4              2         Alhambra  Fast Food Restaurant
#
#    2nd Most Common Venue          3rd Most Common Venue
# 0             Taco Place          Vietnamese Restaurant
# 1       Sushi Restaurant                 Breakfast Spot
# 2         Breakfast Spot                    Pizza Place
# 3  Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 4    Japanese Restaurant             Mexican Restaurant

# %%
# Let's merge the two datasets
la_df_merged = rslt_df
la_df_merged = la_df_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='name') 
la_df_merged.head()
# Out:
#                                    set             slug  \
# 1  L.A. County Neighborhoods (Current)  adams-normandie
# 2  L.A. County Neighborhoods (Current)     agoura-hills
# 4  L.A. County Neighborhoods (Current)         alhambra
# 6  L.A. County Neighborhoods (Current)          artesia
# 9  L.A. County Neighborhoods (Current)          arcadia
#
#                                             the_geom  \
# 1  MULTIPOLYGON (((-118.30900800000012 34.0374109...
# 2  MULTIPOLYGON (((-118.76192500000009 34.1682029...
# 4  MULTIPOLYGON (((-118.12174700000014 34.1050399...
# 6  MULTIPOLYGON (((-118.0748950000001 33.88038299...
# 9  MULTIPOLYGON (((-118.017052 34.177181999122524...
#
#                                  kind       external_i             name  \
# 1  L.A. County Neighborhood (Current)  adams-normandie  Adams-Normandie
# 2  L.A. County Neighborhood (Current)     agoura-hills     Agoura Hills
# 4  L.A. County Neighborhood (Current)         alhambra         Alhambra
# 6  L.A. County Neighborhood (Current)          artesia          Artesia
# 9  L.A. County Neighborhood (Current)          arcadia          Arcadia
#
#                                           display_na       sqmi  \
# 1  Adams-Normandie L.A. County Neighborhood (Curr...   0.805350
# 2    Agoura Hills L.A. County Neighborhood (Current)   8.146760
# 4        Alhambra L.A. County Neighborhood (Current)   7.623814
# 6         Artesia L.A. County Neighborhood (Current)   1.632204
# 9         Arcadia L.A. County Neighborhood (Current)  11.150797
#
#                 type  name_1  slug_1    latitude  longitude  \
# 1  segment-of-a-city     NaN     NaN -118.300208  34.031461
# 2    standalone-city     NaN     NaN -118.759884  34.146736
# 4    standalone-city     NaN     NaN -118.136512  34.085539
# 6    standalone-city     NaN     NaN -118.080101  33.866896
# 9    standalone-city     NaN     NaN -118.030419  34.133230
#
#                                         location  ClusterLabels  \
# 1  POINT(34.031461499124156 -118.30020800000011)            2.0
# 2  POINT(34.146736499122795 -118.75988450000015)            2.0
# 4  POINT(34.085538999123571 -118.13651200000021)            2.0
# 6  POINT(33.866895999126271 -118.08010100000017)            2.0
# 9  POINT(34.133229999123017 -118.03041899311202)            2.0
#
#   1st Most Common Venue          2nd Most Common Venue 3rd Most Common Venue
# 1  Fast Food Restaurant               Sushi Restaurant        Breakfast Spot
# 2  Fast Food Restaurant                 Breakfast Spot           Pizza Place
# 4  Fast Food Restaurant            Japanese Restaurant    Mexican Restaurant
# 6     Korean Restaurant  Vegetarian / Vegan Restaurant            Taco Place
# 9           Pizza Place          Vietnamese Restaurant         Deli / Bodega

# %%
neighborhoods_venues_sorted.loc[neighborhoods_venues_sorted['ClusterLabels'] ==1, neighborhoods_venues_sorted.columns[[1] + list(range(5, neighborhoods_venues_sorted.shape[1]))]]
# Out:
#           Neighborhood
# 8               Arleta
# 40             Del Rey
# 47      East Hollywood
# 52      Elysian Valley
# 58            Glendale
# 81           La Mirada
# 88        Leimert Park
# 96   Mayflower Village
# 114             Pomona

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Build the cluster map uncover areas where there are no clusters.

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# Mapping with Folium
la_map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
x = np.arange(3)
ys = [i + x + (i*x)**2 for i in range(kclusters_num)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]


markers_colors = []

for lon, lat, poi, cluster in zip(la_df_merged['latitude'], la_df_merged['longitude'], la_df_merged['name'], la_df_merged['ClusterLabels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6).add_to(la_map_clusters)
       
la_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_865050cd15f74d0f8fe6f74324834fc3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_865050cd15f74d0f8fe6f74324834fc3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_865050cd15f74d0f8fe6f74324834fc3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_865050cd15f74d0f8fe6f74324834fc3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.0536909%2C%20-118.242766%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# A quick review of the cluster map reveals 4 areas without a cluster as potential neighborhoods to have a restaurant.
#
# <dl>
#     <dt>Granada Hills</dt>
#     <dt>East Los Angeles</dt>
#     <dt>Santa Fe Springs</dt>
# </dl>

# %% [markdown]
# A quick look at a population density map confirms that there are enough people in the neighborhood to potentiallt support a new restaurant.
#
# https://www.arcgis.com/apps/mapviewer/index.html?webmap=5913b5311e6449909e4139117c96a878

# %% [markdown]
# <dl>
#     <dt>Granada Hills has a highly diverse demographic makeup and has a median income of 83,911</dt>
#     <dt>East Los Angeles has a high Latino population (96%) and has a median income of 37,982</dt>
#     <dt>Santa Fe Springs has a high Latino population (70%) and a median income of 54,081</dt>
# </dl>
# (from Wikipedia)

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Both East Los Angeles and Santa Fe Springs would be good candidates for any Mexican or Latino restaurant. Santa Fe Springs has a higher median income, and likely more able to support a mid-priced restaurant.

# %% [markdown]
# Grenada Hills is very good candidate for any mid to high-priced restaurant, potentially of any cuisine, though there is a strong Asian population which could favor one of the sub-Asian populations.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# This analysis is really just the beginning. Many other factors could be explored, zoning for instance, which could affect where to further investigate, but with that, this clustering analysis has provided some initial top recommdations based on the two data sets using KMeans.
